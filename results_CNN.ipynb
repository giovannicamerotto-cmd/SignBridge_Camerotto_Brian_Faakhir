# %%
import csv

import numpy as np
import tensorflow as tf
from sklearn.model_selection import train_test_split

RANDOM_SEED = 42

# %% [markdown]
# # 各パス指定

# %%
dataset = 'model/point_history_classifier/point_history.csv'
model_save_path = 'model/point_history_classifier/point_history_classifier.keras'

# %% [markdown]
# # 分類数設定

# %%
NUM_CLASSES = 5

# %% [markdown]
# # 入力長

# %%
TIME_STEPS = 8 # 8 green circles each finger tip
DIMENSION = 10 # 2 values (x,y) for each of the 5 fingers = 2*5 = 10

# %% [markdown]
# # 学習データ読み込み

# %%
X_dataset = np.loadtxt(dataset, delimiter=',', dtype='float32', usecols=list(range(1, (TIME_STEPS * DIMENSION) + 1)))
# each line of the dataset point_history.csv starts with the finger number 0-4 followed by 160 values

# %%
y_dataset = np.loadtxt(dataset, delimiter=',', dtype='int32', usecols=(0))

# %%
X_train, X_test, y_train, y_test = train_test_split(X_dataset, y_dataset, train_size=0.75, random_state=RANDOM_SEED)
# train_size=0.75 means 75% of input data is used for training, while 25% is used later for validation

# %% [markdown]
# # モデル構築

# %%
arch = "Transformer"
# options:
#   FC (fully connected)
#   CNN (Convolutional Neural Network)
#   Transformer [by default]
model = None

if arch == "FC":
    model = tf.keras.models.Sequential([
            tf.keras.layers.InputLayer(input_shape=(TIME_STEPS * DIMENSION, )),
            tf.keras.layers.Dropout(0.2),
            tf.keras.layers.Dense(24, activation='relu'),
            tf.keras.layers.Dropout(0.5),
            tf.keras.layers.Dense(10, activation='relu'),
            tf.keras.layers.Dense(NUM_CLASSES, activation='softmax')
        ])
elif arch == "CNN":
    model = tf.keras.models.Sequential([
        # 1. Original flat input: (TIME_STEPS * DIMENSION)
        tf.keras.layers.InputLayer(input_shape=(TIME_STEPS * DIMENSION, )),
            
        # 2. Key reshape: transforms data into (TIME_STEPS = )8 time steps (the frames).
        # Each frame contains all x,y coordinates of your points (DIMENSION)
        tf.keras.layers.Reshape((TIME_STEPS, DIMENSION)), 
        tf.keras.layers.Dropout(0.2),
            
        # 3. First Conv1D block: analyzes relationships between points within the same frame
        # and across adjacent frames (temporal window of 3 frames)
        tf.keras.layers.Conv1D(filters=32, kernel_size=3, padding='same', activation='relu'),
        # Reduces the temporal dimension by half (from 8 frames to 4)
        tf.keras.layers.MaxPooling1D(pool_size=2),
            
        # 4. Second Conv1D block: extracts more complex movement patterns
        tf.keras.layers.Conv1D(filters=64, kernel_size=3, padding='same', activation='relu'),
        # Reduces the time dimension further (from 4 frames to 2)
        tf.keras.layers.MaxPooling1D(pool_size=2),
            
        # 5. Flattening and classification (identical to your original structure)
        tf.keras.layers.Flatten(),
        tf.keras.layers.Dropout(0.5),
        tf.keras.layers.Dense(10, activation='relu'),
        tf.keras.layers.Dense(NUM_CLASSES, activation='softmax')
    ])
else:
    # Usiamo le Functional API di Keras poiché i Transformer richiedono connessioni residue (skip connections)
    inputs = tf.keras.layers.Input(shape=(TIME_STEPS * DIMENSION, ))
    
    # 1. Reshape in (TIME_STEPS, DIMENSION)
    x = tf.keras.layers.Reshape((TIME_STEPS, DIMENSION))(inputs)
    x = tf.keras.layers.Dropout(0.2)(x)
    
    # 2. Layer di Self-Attention (il cuore del Transformer)
    # Calcola le relazioni tra i diversi frame temporali
    attention_output = tf.keras.layers.MultiHeadAttention(
        num_heads=4, key_dim=DIMENSION
    )(query=x, value=x, key=x)
    
    # 3. Connessione residua e Normalizzazione
    x = tf.keras.layers.Add()([x, attention_output])
    x = tf.keras.layers.LayerNormalization()(x)
    
    # 4. Riduzione della dimensionalità e classificazione
    x = tf.keras.layers.Flatten()(x)
    x = tf.keras.layers.Dropout(0.5)(x)
    x = tf.keras.layers.Dense(10, activation='relu')(x)
    outputs = tf.keras.layers.Dense(NUM_CLASSES, activation='softmax')(x)
    
    model = tf.keras.models.Model(inputs=inputs, outputs=outputs)
# Out:
# C:\Users\Acer\AppData\Local\Programs\Python\Python310\lib\site-packages\keras\src\layers\core\input_layer.py:27: UserWarning: Argument `input_shape` is deprecated. Use `shape` instead.
#   warnings.warn(

# %%
model.summary()  # tf.keras.utils.plot_model(model, show_shapes=True)
# Out:
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                         ┃ Output Shape                ┃         Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━┩
# │ reshape (Reshape)                    │ (None, 8, 10)               │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dropout (Dropout)                    │ (None, 8, 10)               │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ conv1d (Conv1D)                      │ (None, 8, 32)               │             992 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ max_pooling1d (MaxPooling1D)         │ (None, 4, 32)               │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ conv1d_1 (Conv1D)                    │ (None, 4, 64)               │           6,208 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ max_pooling1d_1 (MaxPooling1D)       │ (None, 2, 64)               │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ flatten (Flatten)                    │ (None, 128)                 │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dropout_1 (Dropout)                  │ (None, 128)                 │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense (Dense)                        │ (None, 10)                  │           1,290 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_1 (Dense)                      │ (None, 5)                   │              55 │
# └──────────────────────────────────────┴─────────────────────────────┴─────────────────┘
#  Total params: 8,545 (33.38 KB)
#  Trainable params: 8,545 (33.38 KB)
#  Non-trainable params: 0 (0.00 B)

# %%
# モデルチェックポイントのコールバック
cp_callback = tf.keras.callbacks.ModelCheckpoint(
    model_save_path, verbose=1, save_weights_only=False)
# 早期打ち切り用コールバック
es_callback = tf.keras.callbacks.EarlyStopping(patience=20, verbose=1)

# %%
# モデルコンパイル
model.compile(
    optimizer='adam',
    loss='sparse_categorical_crossentropy',
    metrics=['accuracy']
)
# Out:
# WARNING:tensorflow:TensorFlow GPU support is not available on native Windows for TensorFlow >= 2.11. Even if CUDA/cuDNN are installed, GPU will not be used. Please use WSL2 or the TensorFlow-DirectML plugin.

# %% [markdown]
# # モデル訓練

# %%
model.fit(
    X_train,
    y_train,
    epochs=1000,
    batch_size=128,
    validation_data=(X_test, y_test), # (see above) 25% of data is used for validation
    callbacks=[cp_callback, es_callback]
)
# Out:
# Epoch 1/1000
# 1/2 ━━━━━━━━━━━━━━━━━━━━ 2s 2s/step - accuracy: 0.1172 - loss: 1.6353
# Epoch 1: saving model to model/point_history_classifier/point_history_classifier.keras
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 3s 501ms/step - accuracy: 0.1123 - loss: 1.6308 - val_accuracy: 0.2381 - val_loss: 1.5839
# Epoch 2/1000
# 1/2 ━━━━━━━━━━━━━━━━━━━━ 0s 62ms/step - accuracy: 0.1953 - loss: 1.6115
# Epoch 2: saving model to model/point_history_classifier/point_history_classifier.keras
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 186ms/step - accuracy: 0.2086 - loss: 1.6033 - val_accuracy: 0.3968 - val_loss: 1.5701
# Epoch 3/1000
# 1/2 ━━━━━━━━━━━━━━━━━━━━ 0s 64ms/step - accuracy: 0.2812 - loss: 1.5787
# Epoch 3: saving model to model/point_history_classifier/point_history_classifier.keras
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 179ms/step - accuracy: 0.2406 - loss: 1.5908 - val_accuracy: 0.4127 - val_loss: 1.5603
# Epoch 4/1000
# 1/2 ━━━━━━━━━━━━━━━━━━━━ 0s 62ms/step - accuracy: 0.2500 - loss: 1.5984
# Epoch 4: saving model to model/point_history_classifier/point_history_classifier.keras
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 178ms/step - accuracy: 0.2834 - loss: 1.5874 - val_accuracy: 0.4286 - val_loss: 1.5529
# Epoch 5/1000
# 1/2 ━━━━━━━━━━━━━━━━━━━━ 0s 65ms/step - accuracy: 0.2812 - loss: 1.5895
# Epoch 5: saving model to model/point_history_classifier/point_history_classifier.keras
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 169ms/step - accuracy: 0.2995 - loss: 1.5762 - val_accuracy: 0.4444 - val_loss: 1.5456
# Epoch 6/1000
# 1/2 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step - accuracy: 0.2422 - loss: 1.5898
# Epoch 6: saving model to model/point_history_classifier/point_history_classifier.keras
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 167ms/step - accuracy: 0.2834 - loss: 1.5680 - val_accuracy: 0.4444 - val_loss: 1.5377
# Epoch 7/1000
# 1/2 ━━━━━━━━━━━━━━━━━━━━ 0s 54ms/step - accuracy: 0.2891 - loss: 1.5890
# Epoch 7: saving model to model/point_history_classifier/point_history_classifier.keras
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 167ms/step - accuracy: 0.3155 - loss: 1.5624 - val_accuracy: 0.4444 - val_loss: 1.5286
# Epoch 8/1000
# 1/2 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step - accuracy: 0.2578 - loss: 1.5752
# Epoch 8: saving model to model/point_history_classifier/point_history_classifier.keras
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 168ms/step - accuracy: 0.2834 - loss: 1.5548 - val_accuracy: 0.4444 - val_loss: 1.5193
# Epoch 9/1000
# 1/2 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step - accuracy: 0.3672 - loss: 1.5205
# Epoch 9: saving model to model/point_history_classifier/point_history_classifier.keras
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 200ms/step - accuracy: 0.3422 - loss: 1.5351 - val_accuracy: 0.4127 - val_loss: 1.5096
# Epoch 10/1000
# 1/2 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step - accuracy: 0.2969 - loss: 1.5607
# Epoch 10: saving model to model/point_history_classifier/point_history_classifier.keras
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 174ms/step - accuracy: 0.3155 - loss: 1.5556 - val_accuracy: 0.4286 - val_loss: 1.5007
# Epoch 11/1000
# 1/2 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step - accuracy: 0.4141 - loss: 1.4984
# Epoch 11: saving model to model/point_history_classifier/point_history_classifier.keras
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 166ms/step - accuracy: 0.3583 - loss: 1.5188 - val_accuracy: 0.4603 - val_loss: 1.4919
# Epoch 12/1000
# 1/2 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step - accuracy: 0.3516 - loss: 1.5366
# Epoch 12: saving model to model/point_history_classifier/point_history_classifier.keras
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 167ms/step - accuracy: 0.3476 - loss: 1.5299 - val_accuracy: 0.4762 - val_loss: 1.4836
# Epoch 13/1000
# 1/2 ━━━━━━━━━━━━━━━━━━━━ 0s 54ms/step - accuracy: 0.3672 - loss: 1.5058
# Epoch 13: saving model to model/point_history_classifier/point_history_classifier.keras
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 167ms/step - accuracy: 0.3797 - loss: 1.5016 - val_accuracy: 0.5079 - val_loss: 1.4746
# Epoch 14/1000
# 1/2 ━━━━━━━━━━━━━━━━━━━━ 0s 53ms/step - accuracy: 0.3594 - loss: 1.5024
# Epoch 14: saving model to model/point_history_classifier/point_history_classifier.keras
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 168ms/step - accuracy: 0.3636 - loss: 1.4986 - val_accuracy: 0.5238 - val_loss: 1.4654
# Epoch 15/1000
# 1/2 ━━━━━━━━━━━━━━━━━━━━ 0s 65ms/step - accuracy: 0.3750 - loss: 1.4937
# Epoch 15: saving model to model/point_history_classifier/point_history_classifier.keras
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 168ms/step - accuracy: 0.3743 - loss: 1.4867 - val_accuracy: 0.4921 - val_loss: 1.4557
# Epoch 16/1000
# 1/2 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step - accuracy: 0.3438 - loss: 1.5128
# Epoch 16: saving model to model/point_history_classifier/point_history_classifier.keras
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 182ms/step - accuracy: 0.3797 - loss: 1.4990 - val_accuracy: 0.4762 - val_loss: 1.4460
# Epoch 17/1000
# 1/2 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step - accuracy: 0.4375 - loss: 1.4596
# Epoch 17: saving model to model/point_history_classifier/point_history_classifier.keras
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 197ms/step - accuracy: 0.4064 - loss: 1.4838 - val_accuracy: 0.4762 - val_loss: 1.4357
# Epoch 18/1000
# 1/2 ━━━━━━━━━━━━━━━━━━━━ 0s 62ms/step - accuracy: 0.4062 - loss: 1.5026
# Epoch 18: saving model to model/point_history_classifier/point_history_classifier.keras
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 165ms/step - accuracy: 0.4332 - loss: 1.4670 - val_accuracy: 0.4921 - val_loss: 1.4258
# Epoch 19/1000
# 1/2 ━━━━━━━━━━━━━━━━━━━━ 0s 63ms/step - accuracy: 0.3516 - loss: 1.4855
# Epoch 19: saving model to model/point_history_classifier/point_history_classifier.keras
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 170ms/step - accuracy: 0.3636 - loss: 1.4657 - val_accuracy: 0.4921 - val_loss: 1.4149
# Epoch 20/1000
# 1/2 ━━━━━━━━━━━━━━━━━━━━ 0s 54ms/step - accuracy: 0.3281 - loss: 1.4726
# Epoch 20: saving model to model/point_history_classifier/point_history_classifier.keras
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 168ms/step - accuracy: 0.3636 - loss: 1.4581 - val_accuracy: 0.5238 - val_loss: 1.4038
# Epoch 21/1000
# 1/2 ━━━━━━━━━━━━━━━━━━━━ 0s 61ms/step - accuracy: 0.4062 - loss: 1.4436
# Epoch 21: saving model to model/point_history_classifier/point_history_classifier.keras
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 174ms/step - accuracy: 0.4171 - loss: 1.4384 - val_accuracy: 0.5556 - val_loss: 1.3926
# Epoch 22/1000
# 1/2 ━━━━━━━━━━━━━━━━━━━━ 0s 54ms/step - accuracy: 0.3672 - loss: 1.4350
# Epoch 22: saving model to model/point_history_classifier/point_history_classifier.keras
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 172ms/step - accuracy: 0.3957 - loss: 1.4245 - val_accuracy: 0.5556 - val_loss: 1.3813
# Epoch 23/1000
# 1/2 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step - accuracy: 0.4297 - loss: 1.4152
# Epoch 23: saving model to model/point_history_classifier/point_history_classifier.keras
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 161ms/step - accuracy: 0.4439 - loss: 1.4018 - val_accuracy: 0.5238 - val_loss: 1.3697
# Epoch 24/1000
# 1/2 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step - accuracy: 0.4297 - loss: 1.4135
# Epoch 24: saving model to model/point_history_classifier/point_history_classifier.keras
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 182ms/step - accuracy: 0.4385 - loss: 1.4074 - val_accuracy: 0.5079 - val_loss: 1.3567
# Epoch 25/1000
# 1/2 ━━━━━━━━━━━━━━━━━━━━ 0s 58ms/step - accuracy: 0.4219 - loss: 1.4260
# Epoch 25: saving model to model/point_history_classifier/point_history_classifier.keras
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 175ms/step - accuracy: 0.4332 - loss: 1.4007 - val_accuracy: 0.5079 - val_loss: 1.3429
# Epoch 26/1000
# 1/2 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step - accuracy: 0.4531 - loss: 1.3503
# Epoch 26: saving model to model/point_history_classifier/point_history_classifier.keras
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 174ms/step - accuracy: 0.4171 - loss: 1.3630 - val_accuracy: 0.5238 - val_loss: 1.3277
# Epoch 27/1000
# 1/2 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step - accuracy: 0.4297 - loss: 1.3417
# Epoch 27: saving model to model/point_history_classifier/point_history_classifier.keras
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 179ms/step - accuracy: 0.4332 - loss: 1.3466 - val_accuracy: 0.5079 - val_loss: 1.3122
# Epoch 28/1000
# 1/2 ━━━━━━━━━━━━━━━━━━━━ 0s 63ms/step - accuracy: 0.3750 - loss: 1.3999
# Epoch 28: saving model to model/point_history_classifier/point_history_classifier.keras
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 184ms/step - accuracy: 0.3850 - loss: 1.3900 - val_accuracy: 0.5079 - val_loss: 1.2974
# Epoch 29/1000
# 1/2 ━━━━━━━━━━━━━━━━━━━━ 0s 61ms/step - accuracy: 0.4688 - loss: 1.3096
# Epoch 29: saving model to model/point_history_classifier/point_history_classifier.keras
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 184ms/step - accuracy: 0.4332 - loss: 1.3258 - val_accuracy: 0.5238 - val_loss: 1.2817
# Epoch 30/1000
# 1/2 ━━━━━━━━━━━━━━━━━━━━ 0s 60ms/step - accuracy: 0.3672 - loss: 1.3838
# Epoch 30: saving model to model/point_history_classifier/point_history_classifier.keras
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 216ms/step - accuracy: 0.4171 - loss: 1.3300 - val_accuracy: 0.5079 - val_loss: 1.2659
# Epoch 31/1000
# 1/2 ━━━━━━━━━━━━━━━━━━━━ 0s 58ms/step - accuracy: 0.3672 - loss: 1.3547
# Epoch 31: saving model to model/point_history_classifier/point_history_classifier.keras
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 168ms/step - accuracy: 0.4118 - loss: 1.3259 - val_accuracy: 0.5397 - val_loss: 1.2489
# Epoch 32/1000
# 1/2 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step - accuracy: 0.4062 - loss: 1.3359
# Epoch 32: saving model to model/point_history_classifier/point_history_classifier.keras
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 160ms/step - accuracy: 0.4118 - loss: 1.3510 - val_accuracy: 0.5397 - val_loss: 1.2327
# Epoch 33/1000
# 1/2 ━━━━━━━━━━━━━━━━━━━━ 0s 64ms/step - accuracy: 0.3984 - loss: 1.3097
# Epoch 33: saving model to model/point_history_classifier/point_history_classifier.keras
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 187ms/step - accuracy: 0.4064 - loss: 1.2853 - val_accuracy: 0.5556 - val_loss: 1.2178
# Epoch 34/1000
# 1/2 ━━━━━━━━━━━━━━━━━━━━ 0s 54ms/step - accuracy: 0.4062 - loss: 1.3195
# Epoch 34: saving model to model/point_history_classifier/point_history_classifier.keras
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 182ms/step - accuracy: 0.4278 - loss: 1.2844 - val_accuracy: 0.5714 - val_loss: 1.2030
# Epoch 35/1000
# 1/2 ━━━━━━━━━━━━━━━━━━━━ 0s 62ms/step - accuracy: 0.4688 - loss: 1.2419
# Epoch 35: saving model to model/point_history_classifier/point_history_classifier.keras
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 162ms/step - accuracy: 0.4439 - loss: 1.2376 - val_accuracy: 0.5714 - val_loss: 1.1882
# Epoch 36/1000
# 1/2 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step - accuracy: 0.4766 - loss: 1.2381
# Epoch 36: saving model to model/point_history_classifier/point_history_classifier.keras
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 171ms/step - accuracy: 0.4652 - loss: 1.2341 - val_accuracy: 0.5714 - val_loss: 1.1725
# Epoch 37/1000
# 1/2 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step - accuracy: 0.5078 - loss: 1.1924
# Epoch 37: saving model to model/point_history_classifier/point_history_classifier.keras
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 164ms/step - accuracy: 0.4706 - loss: 1.2080 - val_accuracy: 0.5714 - val_loss: 1.1555
# Epoch 38/1000
# 1/2 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step - accuracy: 0.5156 - loss: 1.1969
# Epoch 38: saving model to model/point_history_classifier/point_history_classifier.keras
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 166ms/step - accuracy: 0.4813 - loss: 1.1969 - val_accuracy: 0.5556 - val_loss: 1.1392
# Epoch 39/1000
# 1/2 ━━━━━━━━━━━━━━━━━━━━ 0s 63ms/step - accuracy: 0.5000 - loss: 1.1555
# Epoch 39: saving model to model/point_history_classifier/point_history_classifier.keras
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 159ms/step - accuracy: 0.4813 - loss: 1.1824 - val_accuracy: 0.5556 - val_loss: 1.1230
# Epoch 40/1000
# 1/2 ━━━━━━━━━━━━━━━━━━━━ 0s 66ms/step - accuracy: 0.5391 - loss: 1.1633
# Epoch 40: saving model to model/point_history_classifier/point_history_classifier.keras
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 167ms/step - accuracy: 0.5080 - loss: 1.1645 - val_accuracy: 0.5556 - val_loss: 1.1070
# Epoch 41/1000
# 1/2 ━━━━━━━━━━━━━━━━━━━━ 0s 52ms/step - accuracy: 0.4297 - loss: 1.2009
# Epoch 41: saving model to model/point_history_classifier/point_history_classifier.keras
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 164ms/step - accuracy: 0.4759 - loss: 1.1545 - val_accuracy: 0.5556 - val_loss: 1.0903
# Epoch 42/1000
# 1/2 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step - accuracy: 0.5000 - loss: 1.1698
# Epoch 42: saving model to model/point_history_classifier/point_history_classifier.keras
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 162ms/step - accuracy: 0.4920 - loss: 1.1495 - val_accuracy: 0.5714 - val_loss: 1.0738
# Epoch 43/1000
# 1/2 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step - accuracy: 0.5156 - loss: 1.1211
# Epoch 43: saving model to model/point_history_classifier/point_history_classifier.keras
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 173ms/step - accuracy: 0.5294 - loss: 1.0986 - val_accuracy: 0.6032 - val_loss: 1.0590
# Epoch 44/1000
# 1/2 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step - accuracy: 0.5312 - loss: 1.0762
# Epoch 44: saving model to model/point_history_classifier/point_history_classifier.keras
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 172ms/step - accuracy: 0.5187 - loss: 1.1020 - val_accuracy: 0.6190 - val_loss: 1.0468
# Epoch 45/1000
# 1/2 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step - accuracy: 0.5625 - loss: 1.0781
# Epoch 45: saving model to model/point_history_classifier/point_history_classifier.keras
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 159ms/step - accuracy: 0.5294 - loss: 1.0824 - val_accuracy: 0.6190 - val_loss: 1.0331
# Epoch 46/1000
# 1/2 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step - accuracy: 0.5234 - loss: 1.0898
# Epoch 46: saving model to model/point_history_classifier/point_history_classifier.keras
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 170ms/step - accuracy: 0.5348 - loss: 1.0917 - val_accuracy: 0.6190 - val_loss: 1.0168
# Epoch 47/1000
# 1/2 ━━━━━━━━━━━━━━━━━━━━ 0s 53ms/step - accuracy: 0.5703 - loss: 1.0968
# Epoch 47: saving model to model/point_history_classifier/point_history_classifier.keras
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 167ms/step - accuracy: 0.5668 - loss: 1.0796 - val_accuracy: 0.6190 - val_loss: 1.0020
# Epoch 48/1000
# 1/2 ━━━━━━━━━━━━━━━━━━━━ 0s 53ms/step - accuracy: 0.5469 - loss: 1.0639
# Epoch 48: saving model to model/point_history_classifier/point_history_classifier.keras
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 159ms/step - accuracy: 0.5508 - loss: 1.0710 - val_accuracy: 0.6190 - val_loss: 0.9900
# Epoch 49/1000
# 1/2 ━━━━━━━━━━━━━━━━━━━━ 0s 54ms/step - accuracy: 0.5547 - loss: 1.0365
# Epoch 49: saving model to model/point_history_classifier/point_history_classifier.keras
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 157ms/step - accuracy: 0.5829 - loss: 1.0349 - val_accuracy: 0.6349 - val_loss: 0.9780
# Epoch 50/1000
# 1/2 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step - accuracy: 0.6250 - loss: 1.0120
# Epoch 50: saving model to model/point_history_classifier/point_history_classifier.keras
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 175ms/step - accuracy: 0.5882 - loss: 1.0262 - val_accuracy: 0.6349 - val_loss: 0.9653
# Epoch 51/1000
# 1/2 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step - accuracy: 0.6484 - loss: 0.9708
# Epoch 51: saving model to model/point_history_classifier/point_history_classifier.keras
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 187ms/step - accuracy: 0.6471 - loss: 0.9863 - val_accuracy: 0.6349 - val_loss: 0.9534
# Epoch 52/1000
# 1/2 ━━━━━━━━━━━━━━━━━━━━ 0s 68ms/step - accuracy: 0.5781 - loss: 1.0398
# Epoch 52: saving model to model/point_history_classifier/point_history_classifier.keras
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 240ms/step - accuracy: 0.5989 - loss: 1.0346 - val_accuracy: 0.6508 - val_loss: 0.9425
# Epoch 53/1000
# 1/2 ━━━━━━━━━━━━━━━━━━━━ 0s 65ms/step - accuracy: 0.6484 - loss: 1.0062
# Epoch 53: saving model to model/point_history_classifier/point_history_classifier.keras
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 179ms/step - accuracy: 0.6578 - loss: 0.9811 - val_accuracy: 0.6667 - val_loss: 0.9298
# Epoch 54/1000
# 1/2 ━━━━━━━━━━━━━━━━━━━━ 0s 57ms/step - accuracy: 0.6875 - loss: 0.9751
# Epoch 54: saving model to model/point_history_classifier/point_history_classifier.keras
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 195ms/step - accuracy: 0.6791 - loss: 0.9655 - val_accuracy: 0.6825 - val_loss: 0.9178
# Epoch 55/1000
# 1/2 ━━━━━━━━━━━━━━━━━━━━ 0s 58ms/step - accuracy: 0.6562 - loss: 0.9654
# Epoch 55: saving model to model/point_history_classifier/point_history_classifier.keras
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 184ms/step - accuracy: 0.6578 - loss: 0.9661 - val_accuracy: 0.7143 - val_loss: 0.9012
# Epoch 56/1000
# 1/2 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step - accuracy: 0.6875 - loss: 0.9405
# Epoch 56: saving model to model/point_history_classifier/point_history_classifier.keras
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 217ms/step - accuracy: 0.6952 - loss: 0.9438 - val_accuracy: 0.7302 - val_loss: 0.8841
# Epoch 57/1000
# 1/2 ━━━━━━━━━━━━━━━━━━━━ 0s 69ms/step - accuracy: 0.6719 - loss: 0.9279
# Epoch 57: saving model to model/point_history_classifier/point_history_classifier.keras
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 183ms/step - accuracy: 0.7112 - loss: 0.9227 - val_accuracy: 0.7460 - val_loss: 0.8688
# Epoch 58/1000
# 1/2 ━━━━━━━━━━━━━━━━━━━━ 0s 59ms/step - accuracy: 0.7188 - loss: 0.9142
# Epoch 58: saving model to model/point_history_classifier/point_history_classifier.keras
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 190ms/step - accuracy: 0.7433 - loss: 0.9030 - val_accuracy: 0.7460 - val_loss: 0.8535
# Epoch 59/1000
# 1/2 ━━━━━━━━━━━━━━━━━━━━ 0s 69ms/step - accuracy: 0.7266 - loss: 0.8914
# Epoch 59: saving model to model/point_history_classifier/point_history_classifier.keras
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 206ms/step - accuracy: 0.7112 - loss: 0.8899 - val_accuracy: 0.7302 - val_loss: 0.8396
# Epoch 60/1000
# 1/2 ━━━━━━━━━━━━━━━━━━━━ 0s 75ms/step - accuracy: 0.7422 - loss: 0.9260
# Epoch 60: saving model to model/point_history_classifier/point_history_classifier.keras
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 183ms/step - accuracy: 0.7326 - loss: 0.9139 - val_accuracy: 0.7619 - val_loss: 0.8282
# Epoch 61/1000
# 1/2 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step - accuracy: 0.7891 - loss: 0.8471
# Epoch 61: saving model to model/point_history_classifier/point_history_classifier.keras
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 167ms/step - accuracy: 0.7807 - loss: 0.8608 - val_accuracy: 0.7302 - val_loss: 0.8150
# Epoch 62/1000
# 1/2 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step - accuracy: 0.8125 - loss: 0.7894
# Epoch 62: saving model to model/point_history_classifier/point_history_classifier.keras
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 159ms/step - accuracy: 0.7754 - loss: 0.8135 - val_accuracy: 0.7302 - val_loss: 0.8028
# Epoch 63/1000
# 1/2 ━━━━━━━━━━━━━━━━━━━━ 0s 58ms/step - accuracy: 0.7422 - loss: 0.8427
# Epoch 63: saving model to model/point_history_classifier/point_history_classifier.keras
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 188ms/step - accuracy: 0.7487 - loss: 0.8224 - val_accuracy: 0.7460 - val_loss: 0.7923
# Epoch 64/1000
# 1/2 ━━━━━━━━━━━━━━━━━━━━ 0s 53ms/step - accuracy: 0.7188 - loss: 0.7835
# Epoch 64: saving model to model/point_history_classifier/point_history_classifier.keras
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 166ms/step - accuracy: 0.7005 - loss: 0.7940 - val_accuracy: 0.7619 - val_loss: 0.7818
# Epoch 65/1000
# 1/2 ━━━━━━━━━━━━━━━━━━━━ 0s 64ms/step - accuracy: 0.7578 - loss: 0.8480
# Epoch 65: saving model to model/point_history_classifier/point_history_classifier.keras
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 177ms/step - accuracy: 0.7647 - loss: 0.8003 - val_accuracy: 0.7619 - val_loss: 0.7756
# Epoch 66/1000
# 1/2 ━━━━━━━━━━━━━━━━━━━━ 0s 67ms/step - accuracy: 0.7578 - loss: 0.8204
# Epoch 66: saving model to model/point_history_classifier/point_history_classifier.keras
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 166ms/step - accuracy: 0.7861 - loss: 0.7948 - val_accuracy: 0.7778 - val_loss: 0.7656
# Epoch 67/1000
# 1/2 ━━━━━━━━━━━━━━━━━━━━ 0s 66ms/step - accuracy: 0.7812 - loss: 0.7567
# Epoch 67: saving model to model/point_history_classifier/point_history_classifier.keras
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 167ms/step - accuracy: 0.7701 - loss: 0.7774 - val_accuracy: 0.7778 - val_loss: 0.7521
# Epoch 68/1000
# 1/2 ━━━━━━━━━━━━━━━━━━━━ 0s 58ms/step - accuracy: 0.8047 - loss: 0.7822
# Epoch 68: saving model to model/point_history_classifier/point_history_classifier.keras
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 169ms/step - accuracy: 0.8128 - loss: 0.7321 - val_accuracy: 0.7937 - val_loss: 0.7379
# Epoch 69/1000
# 1/2 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step - accuracy: 0.7969 - loss: 0.7306
# Epoch 69: saving model to model/point_history_classifier/point_history_classifier.keras
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 175ms/step - accuracy: 0.8235 - loss: 0.7000 - val_accuracy: 0.8254 - val_loss: 0.7180
# Epoch 70/1000
# 1/2 ━━━━━━━━━━━━━━━━━━━━ 0s 58ms/step - accuracy: 0.8516 - loss: 0.6868
# Epoch 70: saving model to model/point_history_classifier/point_history_classifier.keras
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 166ms/step - accuracy: 0.8449 - loss: 0.6800 - val_accuracy: 0.8254 - val_loss: 0.6984
# Epoch 71/1000
# 1/2 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step - accuracy: 0.8047 - loss: 0.7122
# Epoch 71: saving model to model/point_history_classifier/point_history_classifier.keras
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 175ms/step - accuracy: 0.7754 - loss: 0.7228 - val_accuracy: 0.7937 - val_loss: 0.6760
# Epoch 72/1000
# 1/2 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step - accuracy: 0.8125 - loss: 0.6962
# Epoch 72: saving model to model/point_history_classifier/point_history_classifier.keras
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 161ms/step - accuracy: 0.8289 - loss: 0.6697 - val_accuracy: 0.7937 - val_loss: 0.6567
# Epoch 73/1000
# 1/2 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step - accuracy: 0.8359 - loss: 0.6063
# Epoch 73: saving model to model/point_history_classifier/point_history_classifier.keras
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 173ms/step - accuracy: 0.8342 - loss: 0.6250 - val_accuracy: 0.7937 - val_loss: 0.6425
# Epoch 74/1000
# 1/2 ━━━━━━━━━━━━━━━━━━━━ 0s 61ms/step - accuracy: 0.8203 - loss: 0.6917
# Epoch 74: saving model to model/point_history_classifier/point_history_classifier.keras
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 184ms/step - accuracy: 0.8182 - loss: 0.6774 - val_accuracy: 0.7937 - val_loss: 0.6339
# Epoch 75/1000
# 1/2 ━━━━━━━━━━━━━━━━━━━━ 0s 53ms/step - accuracy: 0.8438 - loss: 0.6299
# Epoch 75: saving model to model/point_history_classifier/point_history_classifier.keras
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 163ms/step - accuracy: 0.8342 - loss: 0.6237 - val_accuracy: 0.8095 - val_loss: 0.6323
# Epoch 76/1000
# 1/2 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step - accuracy: 0.7500 - loss: 0.7020
# Epoch 76: saving model to model/point_history_classifier/point_history_classifier.keras
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 193ms/step - accuracy: 0.7754 - loss: 0.6883 - val_accuracy: 0.8254 - val_loss: 0.6307
# Epoch 77/1000
# 1/2 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step - accuracy: 0.8125 - loss: 0.6205
# Epoch 77: saving model to model/point_history_classifier/point_history_classifier.keras
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 179ms/step - accuracy: 0.8021 - loss: 0.6403 - val_accuracy: 0.8413 - val_loss: 0.6250
# Epoch 78/1000
# 1/2 ━━━━━━━━━━━━━━━━━━━━ 0s 53ms/step - accuracy: 0.7891 - loss: 0.6375
# Epoch 78: saving model to model/point_history_classifier/point_history_classifier.keras
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 192ms/step - accuracy: 0.8075 - loss: 0.6301 - val_accuracy: 0.8571 - val_loss: 0.6035
# Epoch 79/1000
# 1/2 ━━━━━━━━━━━━━━━━━━━━ 0s 61ms/step - accuracy: 0.7969 - loss: 0.6223
# Epoch 79: saving model to model/point_history_classifier/point_history_classifier.keras
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 191ms/step - accuracy: 0.7968 - loss: 0.6270 - val_accuracy: 0.8571 - val_loss: 0.5781
# Epoch 80/1000
# 1/2 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step - accuracy: 0.8281 - loss: 0.5679
# Epoch 80: saving model to model/point_history_classifier/point_history_classifier.keras
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 185ms/step - accuracy: 0.8449 - loss: 0.5736 - val_accuracy: 0.8571 - val_loss: 0.5557
# Epoch 81/1000
# 1/2 ━━━━━━━━━━━━━━━━━━━━ 0s 53ms/step - accuracy: 0.8203 - loss: 0.5627
# Epoch 81: saving model to model/point_history_classifier/point_history_classifier.keras
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 179ms/step - accuracy: 0.8128 - loss: 0.5698 - val_accuracy: 0.8413 - val_loss: 0.5417
# Epoch 82/1000
# 1/2 ━━━━━━━━━━━━━━━━━━━━ 0s 58ms/step - accuracy: 0.7500 - loss: 0.6319
# Epoch 82: saving model to model/point_history_classifier/point_history_classifier.keras
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 156ms/step - accuracy: 0.7754 - loss: 0.5961 - val_accuracy: 0.8254 - val_loss: 0.5355
# Epoch 83/1000
# 1/2 ━━━━━━━━━━━━━━━━━━━━ 0s 72ms/step - accuracy: 0.8281 - loss: 0.5346
# Epoch 83: saving model to model/point_history_classifier/point_history_classifier.keras
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 176ms/step - accuracy: 0.8289 - loss: 0.5613 - val_accuracy: 0.8413 - val_loss: 0.5292
# Epoch 84/1000
# 1/2 ━━━━━━━━━━━━━━━━━━━━ 0s 53ms/step - accuracy: 0.8047 - loss: 0.5455
# Epoch 84: saving model to model/point_history_classifier/point_history_classifier.keras
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 186ms/step - accuracy: 0.8021 - loss: 0.5961 - val_accuracy: 0.8413 - val_loss: 0.5186
# Epoch 85/1000
# 1/2 ━━━━━━━━━━━━━━━━━━━━ 0s 52ms/step - accuracy: 0.8516 - loss: 0.5495
# Epoch 85: saving model to model/point_history_classifier/point_history_classifier.keras
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 174ms/step - accuracy: 0.8449 - loss: 0.5425 - val_accuracy: 0.8571 - val_loss: 0.5126
# Epoch 86/1000
# 1/2 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step - accuracy: 0.8203 - loss: 0.5183
# Epoch 86: saving model to model/point_history_classifier/point_history_classifier.keras
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 163ms/step - accuracy: 0.8396 - loss: 0.4910 - val_accuracy: 0.8730 - val_loss: 0.5088
# Epoch 87/1000
# 1/2 ━━━━━━━━━━━━━━━━━━━━ 0s 53ms/step - accuracy: 0.8125 - loss: 0.5162
# Epoch 87: saving model to model/point_history_classifier/point_history_classifier.keras
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 214ms/step - accuracy: 0.8182 - loss: 0.5108 - val_accuracy: 0.8571 - val_loss: 0.5053
# Epoch 88/1000
# 1/2 ━━━━━━━━━━━━━━━━━━━━ 0s 57ms/step - accuracy: 0.8281 - loss: 0.5293
# Epoch 88: saving model to model/point_history_classifier/point_history_classifier.keras
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 217ms/step - accuracy: 0.8342 - loss: 0.5247 - val_accuracy: 0.8413 - val_loss: 0.4937
# Epoch 89/1000
# 1/2 ━━━━━━━━━━━━━━━━━━━━ 0s 66ms/step - accuracy: 0.8438 - loss: 0.4877
# Epoch 89: saving model to model/point_history_classifier/point_history_classifier.keras
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 267ms/step - accuracy: 0.8396 - loss: 0.5163 - val_accuracy: 0.8095 - val_loss: 0.4774
# Epoch 90/1000
# 1/2 ━━━━━━━━━━━━━━━━━━━━ 0s 91ms/step - accuracy: 0.8750 - loss: 0.4676
# Epoch 90: saving model to model/point_history_classifier/point_history_classifier.keras
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 289ms/step - accuracy: 0.8824 - loss: 0.4440 - val_accuracy: 0.8254 - val_loss: 0.4634
# Epoch 91/1000
# 1/2 ━━━━━━━━━━━━━━━━━━━━ 0s 63ms/step - accuracy: 0.9062 - loss: 0.3890
# Epoch 91: saving model to model/point_history_classifier/point_history_classifier.keras
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 179ms/step - accuracy: 0.8877 - loss: 0.4452 - val_accuracy: 0.8413 - val_loss: 0.4503
# Epoch 92/1000
# 1/2 ━━━━━━━━━━━━━━━━━━━━ 0s 54ms/step - accuracy: 0.8984 - loss: 0.3814
# Epoch 92: saving model to model/point_history_classifier/point_history_classifier.keras
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 206ms/step - accuracy: 0.8930 - loss: 0.3867 - val_accuracy: 0.8413 - val_loss: 0.4389
# Epoch 93/1000
# 1/2 ━━━━━━━━━━━━━━━━━━━━ 0s 72ms/step - accuracy: 0.8672 - loss: 0.4840
# Epoch 93: saving model to model/point_history_classifier/point_history_classifier.keras
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 183ms/step - accuracy: 0.8717 - loss: 0.4512 - val_accuracy: 0.8571 - val_loss: 0.4345
# Epoch 94/1000
# 1/2 ━━━━━━━━━━━━━━━━━━━━ 0s 54ms/step - accuracy: 0.8594 - loss: 0.5061
# Epoch 94: saving model to model/point_history_classifier/point_history_classifier.keras
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 170ms/step - accuracy: 0.8824 - loss: 0.4683 - val_accuracy: 0.8571 - val_loss: 0.4386
# Epoch 95/1000
# 1/2 ━━━━━━━━━━━━━━━━━━━━ 0s 54ms/step - accuracy: 0.8906 - loss: 0.4157
# Epoch 95: saving model to model/point_history_classifier/point_history_classifier.keras
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 182ms/step - accuracy: 0.8877 - loss: 0.4201 - val_accuracy: 0.8571 - val_loss: 0.4395
# Epoch 96/1000
# 1/2 ━━━━━━━━━━━━━━━━━━━━ 0s 53ms/step - accuracy: 0.9141 - loss: 0.3967
# Epoch 96: saving model to model/point_history_classifier/point_history_classifier.keras
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 172ms/step - accuracy: 0.8770 - loss: 0.4202 - val_accuracy: 0.8730 - val_loss: 0.4319
# Epoch 97/1000
# 1/2 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step - accuracy: 0.8203 - loss: 0.4857
# Epoch 97: saving model to model/point_history_classifier/point_history_classifier.keras
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 177ms/step - accuracy: 0.8342 - loss: 0.4459 - val_accuracy: 0.8413 - val_loss: 0.4207
# Epoch 98/1000
# 1/2 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step - accuracy: 0.8359 - loss: 0.4442
# Epoch 98: saving model to model/point_history_classifier/point_history_classifier.keras
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 185ms/step - accuracy: 0.8610 - loss: 0.4246 - val_accuracy: 0.8571 - val_loss: 0.4111
# Epoch 99/1000
# 1/2 ━━━━━━━━━━━━━━━━━━━━ 0s 66ms/step - accuracy: 0.9062 - loss: 0.3503
# Epoch 99: saving model to model/point_history_classifier/point_history_classifier.keras
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 163ms/step - accuracy: 0.9198 - loss: 0.3398 - val_accuracy: 0.8730 - val_loss: 0.4024
# Epoch 100/1000
# 1/2 ━━━━━━━━━━━━━━━━━━━━ 0s 59ms/step - accuracy: 0.8672 - loss: 0.4504
# Epoch 100: saving model to model/point_history_classifier/point_history_classifier.keras
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 174ms/step - accuracy: 0.8503 - loss: 0.4655 - val_accuracy: 0.8889 - val_loss: 0.3976
# Epoch 101/1000
# 1/2 ━━━━━━━━━━━━━━━━━━━━ 0s 52ms/step - accuracy: 0.8828 - loss: 0.3144
# Epoch 101: saving model to model/point_history_classifier/point_history_classifier.keras
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 177ms/step - accuracy: 0.9037 - loss: 0.3333 - val_accuracy: 0.8889 - val_loss: 0.3974
# Epoch 102/1000
# 1/2 ━━━━━━━━━━━━━━━━━━━━ 0s 54ms/step - accuracy: 0.8906 - loss: 0.3704
# Epoch 102: saving model to model/point_history_classifier/point_history_classifier.keras
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 168ms/step - accuracy: 0.8930 - loss: 0.3560 - val_accuracy: 0.8889 - val_loss: 0.4067
# Epoch 103/1000
# 1/2 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step - accuracy: 0.8281 - loss: 0.4209
# Epoch 103: saving model to model/point_history_classifier/point_history_classifier.keras
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 160ms/step - accuracy: 0.8449 - loss: 0.3999 - val_accuracy: 0.8730 - val_loss: 0.4157
# Epoch 104/1000
# 1/2 ━━━━━━━━━━━━━━━━━━━━ 0s 63ms/step - accuracy: 0.8672 - loss: 0.3735
# Epoch 104: saving model to model/point_history_classifier/point_history_classifier.keras
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 179ms/step - accuracy: 0.8717 - loss: 0.3622 - val_accuracy: 0.8730 - val_loss: 0.4123
# Epoch 105/1000
# 1/2 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step - accuracy: 0.8750 - loss: 0.3773
# Epoch 105: saving model to model/point_history_classifier/point_history_classifier.keras
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 170ms/step - accuracy: 0.8770 - loss: 0.3596 - val_accuracy: 0.8730 - val_loss: 0.3893
# Epoch 106/1000
# 1/2 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step - accuracy: 0.9219 - loss: 0.3113
# Epoch 106: saving model to model/point_history_classifier/point_history_classifier.keras
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 166ms/step - accuracy: 0.9305 - loss: 0.3086 - val_accuracy: 0.8889 - val_loss: 0.3713
# Epoch 107/1000
# 1/2 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step - accuracy: 0.9219 - loss: 0.2759
# Epoch 107: saving model to model/point_history_classifier/point_history_classifier.keras
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 164ms/step - accuracy: 0.9144 - loss: 0.2870 - val_accuracy: 0.9048 - val_loss: 0.3613
# Epoch 108/1000
# 1/2 ━━━━━━━━━━━━━━━━━━━━ 0s 63ms/step - accuracy: 0.8750 - loss: 0.3160
# Epoch 108: saving model to model/point_history_classifier/point_history_classifier.keras
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 169ms/step - accuracy: 0.8877 - loss: 0.3163 - val_accuracy: 0.9048 - val_loss: 0.3512
# Epoch 109/1000
# 1/2 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step - accuracy: 0.8984 - loss: 0.3656
# Epoch 109: saving model to model/point_history_classifier/point_history_classifier.keras
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 174ms/step - accuracy: 0.8824 - loss: 0.3598 - val_accuracy: 0.9048 - val_loss: 0.3469
# Epoch 110/1000
# 1/2 ━━━━━━━━━━━━━━━━━━━━ 0s 60ms/step - accuracy: 0.9375 - loss: 0.2928
# Epoch 110: saving model to model/point_history_classifier/point_history_classifier.keras
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 164ms/step - accuracy: 0.9037 - loss: 0.3261 - val_accuracy: 0.9048 - val_loss: 0.3450
# Epoch 111/1000
# 1/2 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step - accuracy: 0.9062 - loss: 0.3731
# Epoch 111: saving model to model/point_history_classifier/point_history_classifier.keras
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 159ms/step - accuracy: 0.9091 - loss: 0.3519 - val_accuracy: 0.9048 - val_loss: 0.3454
# Epoch 112/1000
# 1/2 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step - accuracy: 0.8984 - loss: 0.3153
# Epoch 112: saving model to model/point_history_classifier/point_history_classifier.keras
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 179ms/step - accuracy: 0.8930 - loss: 0.3257 - val_accuracy: 0.9048 - val_loss: 0.3458
# Epoch 113/1000
# 1/2 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step - accuracy: 0.8594 - loss: 0.3274
# Epoch 113: saving model to model/point_history_classifier/point_history_classifier.keras
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 190ms/step - accuracy: 0.8610 - loss: 0.3397 - val_accuracy: 0.9048 - val_loss: 0.3494
# Epoch 114/1000
# 1/2 ━━━━━━━━━━━━━━━━━━━━ 0s 54ms/step - accuracy: 0.9062 - loss: 0.3301
# Epoch 114: saving model to model/point_history_classifier/point_history_classifier.keras
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 160ms/step - accuracy: 0.9305 - loss: 0.3126 - val_accuracy: 0.9048 - val_loss: 0.3489
# Epoch 115/1000
# 1/2 ━━━━━━━━━━━━━━━━━━━━ 0s 58ms/step - accuracy: 0.9375 - loss: 0.3002
# Epoch 115: saving model to model/point_history_classifier/point_history_classifier.keras
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 165ms/step - accuracy: 0.9091 - loss: 0.3220 - val_accuracy: 0.8889 - val_loss: 0.3438
# Epoch 116/1000
# 1/2 ━━━━━━━━━━━━━━━━━━━━ 0s 59ms/step - accuracy: 0.9453 - loss: 0.2745
# Epoch 116: saving model to model/point_history_classifier/point_history_classifier.keras
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 179ms/step - accuracy: 0.9198 - loss: 0.2978 - val_accuracy: 0.8889 - val_loss: 0.3349
# Epoch 117/1000
# 1/2 ━━━━━━━━━━━━━━━━━━━━ 0s 57ms/step - accuracy: 0.9141 - loss: 0.2887
# Epoch 117: saving model to model/point_history_classifier/point_history_classifier.keras
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 166ms/step - accuracy: 0.9251 - loss: 0.2611 - val_accuracy: 0.9048 - val_loss: 0.3320
# Epoch 118/1000
# 1/2 ━━━━━━━━━━━━━━━━━━━━ 0s 52ms/step - accuracy: 0.8984 - loss: 0.2871
# Epoch 118: saving model to model/point_history_classifier/point_history_classifier.keras
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 169ms/step - accuracy: 0.8930 - loss: 0.3100 - val_accuracy: 0.9048 - val_loss: 0.3278
# Epoch 119/1000
# 1/2 ━━━━━━━━━━━━━━━━━━━━ 0s 54ms/step - accuracy: 0.8438 - loss: 0.3707
# Epoch 119: saving model to model/point_history_classifier/point_history_classifier.keras
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 181ms/step - accuracy: 0.8610 - loss: 0.3465 - val_accuracy: 0.9048 - val_loss: 0.3264
# Epoch 120/1000
# 1/2 ━━━━━━━━━━━━━━━━━━━━ 0s 53ms/step - accuracy: 0.9141 - loss: 0.2495
# Epoch 120: saving model to model/point_history_classifier/point_history_classifier.keras
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 179ms/step - accuracy: 0.8984 - loss: 0.2747 - val_accuracy: 0.9206 - val_loss: 0.3323
# Epoch 121/1000
# 1/2 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step - accuracy: 0.9141 - loss: 0.2628
# Epoch 121: saving model to model/point_history_classifier/point_history_classifier.keras
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 183ms/step - accuracy: 0.9144 - loss: 0.2793 - val_accuracy: 0.9048 - val_loss: 0.3381
# Epoch 122/1000
# 1/2 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step - accuracy: 0.9062 - loss: 0.2751
# Epoch 122: saving model to model/point_history_classifier/point_history_classifier.keras
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 167ms/step - accuracy: 0.9198 - loss: 0.2606 - val_accuracy: 0.9206 - val_loss: 0.3347
# Epoch 123/1000
# 1/2 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step - accuracy: 0.9219 - loss: 0.2489
# Epoch 123: saving model to model/point_history_classifier/point_history_classifier.keras
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 164ms/step - accuracy: 0.8984 - loss: 0.2770 - val_accuracy: 0.9048 - val_loss: 0.3200
# Epoch 124/1000
# 1/2 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step - accuracy: 0.8984 - loss: 0.2604
# Epoch 124: saving model to model/point_history_classifier/point_history_classifier.keras
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 190ms/step - accuracy: 0.9144 - loss: 0.2546 - val_accuracy: 0.9206 - val_loss: 0.3081
# Epoch 125/1000
# 1/2 ━━━━━━━━━━━━━━━━━━━━ 0s 63ms/step - accuracy: 0.9531 - loss: 0.2159
# Epoch 125: saving model to model/point_history_classifier/point_history_classifier.keras
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 160ms/step - accuracy: 0.9305 - loss: 0.2640 - val_accuracy: 0.9048 - val_loss: 0.2966
# Epoch 126/1000
# 1/2 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step - accuracy: 0.9453 - loss: 0.2436
# Epoch 126: saving model to model/point_history_classifier/point_history_classifier.keras
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 176ms/step - accuracy: 0.9358 - loss: 0.2532 - val_accuracy: 0.9048 - val_loss: 0.2901
# Epoch 127/1000
# 1/2 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step - accuracy: 0.8750 - loss: 0.2841
# Epoch 127: saving model to model/point_history_classifier/point_history_classifier.keras
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 175ms/step - accuracy: 0.8984 - loss: 0.2611 - val_accuracy: 0.9048 - val_loss: 0.2870
# Epoch 128/1000
# 1/2 ━━━━━━━━━━━━━━━━━━━━ 0s 64ms/step - accuracy: 0.9219 - loss: 0.2710
# Epoch 128: saving model to model/point_history_classifier/point_history_classifier.keras
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 232ms/step - accuracy: 0.9037 - loss: 0.2922 - val_accuracy: 0.9048 - val_loss: 0.2857
# Epoch 129/1000
# 1/2 ━━━━━━━━━━━━━━━━━━━━ 0s 62ms/step - accuracy: 0.8984 - loss: 0.3158
# Epoch 129: saving model to model/point_history_classifier/point_history_classifier.keras
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 212ms/step - accuracy: 0.9144 - loss: 0.2854 - val_accuracy: 0.9206 - val_loss: 0.2861
# Epoch 130/1000
# 1/2 ━━━━━━━━━━━━━━━━━━━━ 0s 61ms/step - accuracy: 0.9531 - loss: 0.2124
# Epoch 130: saving model to model/point_history_classifier/point_history_classifier.keras
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 175ms/step - accuracy: 0.9412 - loss: 0.2274 - val_accuracy: 0.9206 - val_loss: 0.2852
# Epoch 131/1000
# 1/2 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step - accuracy: 0.9141 - loss: 0.2320
# Epoch 131: saving model to model/point_history_classifier/point_history_classifier.keras
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 174ms/step - accuracy: 0.8984 - loss: 0.2838 - val_accuracy: 0.9206 - val_loss: 0.2898
# Epoch 132/1000
# 1/2 ━━━━━━━━━━━━━━━━━━━━ 0s 53ms/step - accuracy: 0.9219 - loss: 0.2269
# Epoch 132: saving model to model/point_history_classifier/point_history_classifier.keras
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 174ms/step - accuracy: 0.9144 - loss: 0.2528 - val_accuracy: 0.9206 - val_loss: 0.2964
# Epoch 133/1000
# 1/2 ━━━━━━━━━━━━━━━━━━━━ 0s 54ms/step - accuracy: 0.9219 - loss: 0.2450
# Epoch 133: saving model to model/point_history_classifier/point_history_classifier.keras
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 177ms/step - accuracy: 0.9305 - loss: 0.2312 - val_accuracy: 0.9206 - val_loss: 0.3021
# Epoch 134/1000
# 1/2 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step - accuracy: 0.8984 - loss: 0.2624
# Epoch 134: saving model to model/point_history_classifier/point_history_classifier.keras
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 171ms/step - accuracy: 0.9091 - loss: 0.2483 - val_accuracy: 0.9206 - val_loss: 0.3054
# Epoch 135/1000
# 1/2 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step - accuracy: 0.9219 - loss: 0.2377
# Epoch 135: saving model to model/point_history_classifier/point_history_classifier.keras
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 174ms/step - accuracy: 0.9305 - loss: 0.2466 - val_accuracy: 0.9206 - val_loss: 0.3060
# Epoch 136/1000
# 1/2 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step - accuracy: 0.9219 - loss: 0.2592
# Epoch 136: saving model to model/point_history_classifier/point_history_classifier.keras
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 179ms/step - accuracy: 0.9144 - loss: 0.2473 - val_accuracy: 0.9206 - val_loss: 0.3042
# Epoch 137/1000
# 1/2 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step - accuracy: 0.9531 - loss: 0.1976
# Epoch 137: saving model to model/point_history_classifier/point_history_classifier.keras
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 173ms/step - accuracy: 0.9572 - loss: 0.2202 - val_accuracy: 0.9206 - val_loss: 0.3040
# Epoch 138/1000
# 1/2 ━━━━━━━━━━━━━━━━━━━━ 0s 54ms/step - accuracy: 0.9375 - loss: 0.1826
# Epoch 138: saving model to model/point_history_classifier/point_history_classifier.keras
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 180ms/step - accuracy: 0.9251 - loss: 0.1911 - val_accuracy: 0.9206 - val_loss: 0.3041
# Epoch 139/1000
# 1/2 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step - accuracy: 0.9375 - loss: 0.2217
# Epoch 139: saving model to model/point_history_classifier/point_history_classifier.keras
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 173ms/step - accuracy: 0.9412 - loss: 0.2075 - val_accuracy: 0.9206 - val_loss: 0.3070
# Epoch 140/1000
# 1/2 ━━━━━━━━━━━━━━━━━━━━ 0s 57ms/step - accuracy: 0.8984 - loss: 0.2511
# Epoch 140: saving model to model/point_history_classifier/point_history_classifier.keras
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 177ms/step - accuracy: 0.9144 - loss: 0.2413 - val_accuracy: 0.9206 - val_loss: 0.3105
# Epoch 141/1000
# 1/2 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step - accuracy: 0.9297 - loss: 0.2172
# Epoch 141: saving model to model/point_history_classifier/point_history_classifier.keras
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 172ms/step - accuracy: 0.9305 - loss: 0.2128 - val_accuracy: 0.9206 - val_loss: 0.3102
# Epoch 142/1000
# 1/2 ━━━━━━━━━━━━━━━━━━━━ 0s 53ms/step - accuracy: 0.9062 - loss: 0.3172
# Epoch 142: saving model to model/point_history_classifier/point_history_classifier.keras
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 181ms/step - accuracy: 0.9091 - loss: 0.3072 - val_accuracy: 0.9206 - val_loss: 0.3065
# Epoch 143/1000
# 1/2 ━━━━━━━━━━━━━━━━━━━━ 0s 69ms/step - accuracy: 0.9453 - loss: 0.2151
# Epoch 143: saving model to model/point_history_classifier/point_history_classifier.keras
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 206ms/step - accuracy: 0.9251 - loss: 0.2301 - val_accuracy: 0.9206 - val_loss: 0.2997
# Epoch 144/1000
# 1/2 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step - accuracy: 0.9219 - loss: 0.2154
# Epoch 144: saving model to model/point_history_classifier/point_history_classifier.keras
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 185ms/step - accuracy: 0.9358 - loss: 0.1990 - val_accuracy: 0.9365 - val_loss: 0.2956
# Epoch 145/1000
# 1/2 ━━━━━━━━━━━━━━━━━━━━ 0s 53ms/step - accuracy: 0.9609 - loss: 0.1592
# Epoch 145: saving model to model/point_history_classifier/point_history_classifier.keras
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 175ms/step - accuracy: 0.9465 - loss: 0.2144 - val_accuracy: 0.9048 - val_loss: 0.2962
# Epoch 146/1000
# 1/2 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step - accuracy: 0.9531 - loss: 0.2225
# Epoch 146: saving model to model/point_history_classifier/point_history_classifier.keras
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 176ms/step - accuracy: 0.9465 - loss: 0.2206 - val_accuracy: 0.9048 - val_loss: 0.2993
# Epoch 147/1000
# 1/2 ━━━━━━━━━━━━━━━━━━━━ 0s 52ms/step - accuracy: 0.9375 - loss: 0.2245
# Epoch 147: saving model to model/point_history_classifier/point_history_classifier.keras
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 175ms/step - accuracy: 0.9358 - loss: 0.2215 - val_accuracy: 0.9048 - val_loss: 0.3026
# Epoch 148/1000
# 1/2 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step - accuracy: 0.9531 - loss: 0.1903
# Epoch 148: saving model to model/point_history_classifier/point_history_classifier.keras
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 174ms/step - accuracy: 0.9465 - loss: 0.1811 - val_accuracy: 0.9048 - val_loss: 0.3073
# Epoch 149/1000
# 1/2 ━━━━━━━━━━━━━━━━━━━━ 0s 57ms/step - accuracy: 0.9141 - loss: 0.2272
# Epoch 149: saving model to model/point_history_classifier/point_history_classifier.keras
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 173ms/step - accuracy: 0.8930 - loss: 0.2672 - val_accuracy: 0.9048 - val_loss: 0.3107
# Epoch 150/1000
# 1/2 ━━━━━━━━━━━━━━━━━━━━ 0s 53ms/step - accuracy: 0.9297 - loss: 0.2308
# Epoch 150: saving model to model/point_history_classifier/point_history_classifier.keras
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 178ms/step - accuracy: 0.9144 - loss: 0.2387 - val_accuracy: 0.9206 - val_loss: 0.3051
# Epoch 150: early stopping

# %%
# 保存したモデルのロード
model = tf.keras.models.load_model(model_save_path)

# %%
# 推論テスト
predict_result = model.predict(np.array([X_test[0]]))
print(np.squeeze(predict_result))
print(np.argmax(np.squeeze(predict_result)))
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 166ms/step
# [8.4346242e-04 7.9955392e-02 5.0840464e-07 9.1907316e-01 1.2744754e-04]
# 3

# %% [markdown]
# # 混同行列

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
from sklearn.metrics import confusion_matrix, classification_report

def print_confusion_matrix(y_true, y_pred, report=True):
    labels = sorted(list(set(y_true)))
    cmx_data = confusion_matrix(y_true, y_pred, labels=labels)
    
    df_cmx = pd.DataFrame(cmx_data, index=labels, columns=labels)
 
    fig, ax = plt.subplots(figsize=(7, 6))
    sns.heatmap(df_cmx, annot=True, fmt='g' ,square=False)
    ax.set_ylim(len(set(y_true)), 0)
    plt.show()
    
    if report:
        print('Classification Report')
        print(classification_report(y_test, y_pred))

Y_pred = model.predict(X_test)
y_pred = np.argmax(Y_pred, axis=1)

print_confusion_matrix(y_test, y_pred)
# horizontal axis: real class
# vertical axis: predicted class
# on the diagonal true predictions, other areas are false predictions
# Out:
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step
# Classification Report
#               precision    recall  f1-score   support
#
#            0       1.00      0.87      0.93        15
#            1       0.89      0.80      0.84        10
#            2       0.87      1.00      0.93        13
#            3       0.95      0.95      0.95        19
#            4       0.86      1.00      0.92         6
#
#     accuracy                           0.92        63
#    macro avg       0.91      0.92      0.91        63
# weighted avg       0.93      0.92      0.92        63

# %% [markdown]
# # Tensorflow-Lite用のモデルへ変換

# %%
# 推論専用のモデルとして保存
 # old but what metters? you can keep it
#model.save(model_save_path, include_optimizer=False)
#model = tf.keras.models.load_model(model_save_path)

# %%
tflite_save_path = 'model/point_history_classifier/point_history_classifier.tflite'

# %%
# モデルを変換(量子化
converter = tf.lite.TFLiteConverter.from_keras_model(model)  # converter = tf.lite.TFLiteConverter.from_saved_model(saved_model_path)
#converter.optimizations = [tf.lite.Optimize.DEFAULT] #old, try again this but nothing
converter.target_spec.supported_ops = [
    tf.lite.OpsSet.TFLITE_BUILTINS,
]
tflite_quantized_model = converter.convert()

open(tflite_save_path, 'wb').write(tflite_quantized_model)
# Out:
# INFO:tensorflow:Assets written to: C:\Users\Acer\AppData\Local\Temp\tmpt84vemsx\assets
# INFO:tensorflow:Assets written to: C:\Users\Acer\AppData\Local\Temp\tmpt84vemsx\assets
# Saved artifact at 'C:\Users\Acer\AppData\Local\Temp\tmpt84vemsx'. The following endpoints are available:
#
# * Endpoint 'serve'
#   args_0 (POSITIONAL_ONLY): TensorSpec(shape=(None, 80), dtype=tf.float32, name='input_layer')
# Output Type:
#   TensorSpec(shape=(None, 5), dtype=tf.float32, name=None)
# Captures:
#   1548747365136: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1548747365312: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1548719764960: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1548781029504: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1548781041648: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1548781537760: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1548781542688: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1548781543392: TensorSpec(shape=(), dtype=tf.resource, name=None)
# 41780

# %% [markdown]
# # 推論テスト

# %%
interpreter = tf.lite.Interpreter(model_path=tflite_save_path)
interpreter.allocate_tensors()
# Out:
# C:\Users\Acer\AppData\Local\Programs\Python\Python310\lib\site-packages\tensorflow\lite\python\interpreter.py:457: UserWarning:     Warning: tf.lite.Interpreter is deprecated and is scheduled for deletion in
#     TF 2.20. Please use the LiteRT interpreter from the ai_edge_litert package.
#     See the [migration guide](https://ai.google.dev/edge/litert/migration)
#     for details.
#
#   warnings.warn(_INTERPRETER_DELETION_WARNING)

# %%
# 入出力テンソルを取得
input_details = interpreter.get_input_details()
output_details = interpreter.get_output_details()
print(input_details)
# Out:
# [{'name': 'serving_default_input_layer:0', 'index': 0, 'shape': array([ 1, 80], dtype=int32), 'shape_signature': array([-1, 80], dtype=int32), 'dtype': <class 'numpy.float32'>, 'quantization': (0.0, 0), 'quantization_parameters': {'scales': array([], dtype=float32), 'zero_points': array([], dtype=int32), 'quantized_dimension': 0, 'block_size': 0}, 'sparsity_parameters': {}}]

# %%
interpreter.set_tensor(input_details[0]['index'], np.array([X_test[0]]))

# %%
# %%time
# 推論実施
interpreter.invoke()
tflite_results = interpreter.get_tensor(output_details[0]['index'])
# Out:
# CPU times: total: 0 ns
# Wall time: 2.99 ms

# %%
print(np.squeeze(tflite_results))
print(np.argmax(np.squeeze(tflite_results)))
# Out:
# [8.4346288e-04 7.9955444e-02 5.0840561e-07 9.1907316e-01 1.2744765e-04]
# 3
