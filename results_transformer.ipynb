# %%
import csv

import numpy as np
import tensorflow as tf
from sklearn.model_selection import train_test_split

RANDOM_SEED = 42

# %% [markdown]
# # 各パス指定

# %%
dataset = 'model/point_history_classifier/point_history.csv'
model_save_path = 'model/point_history_classifier/point_history_classifier.keras'

# %% [markdown]
# # 分類数設定

# %%
NUM_CLASSES = 5

# %% [markdown]
# # 入力長

# %%
TIME_STEPS = 8 # 8 green circles each finger tip
DIMENSION = 10 # 2 values (x,y) for each of the 5 fingers = 2*5 = 10

# %% [markdown]
# # 学習データ読み込み

# %%
X_dataset = np.loadtxt(dataset, delimiter=',', dtype='float32', usecols=list(range(1, (TIME_STEPS * DIMENSION) + 1)))
# each line of the dataset point_history.csv starts with the finger number 0-4 followed by 160 values

# %%
y_dataset = np.loadtxt(dataset, delimiter=',', dtype='int32', usecols=(0))

# %%
X_train, X_test, y_train, y_test = train_test_split(X_dataset, y_dataset, train_size=0.75, random_state=RANDOM_SEED)
# train_size=0.75 means 75% of input data is used for training, while 25% is used later for validation

# %% [markdown]
# # モデル構築

# %%
arch = "Transformer"
# options:
#   FC (fully connected)
#   CNN (Convolutional Neural Network)
#   Transformer [by default]
model = None

if arch == "FC":
    model = tf.keras.models.Sequential([
            tf.keras.layers.InputLayer(input_shape=(TIME_STEPS * DIMENSION, )),
            tf.keras.layers.Dropout(0.2),
            tf.keras.layers.Dense(24, activation='relu'),
            tf.keras.layers.Dropout(0.5),
            tf.keras.layers.Dense(10, activation='relu'),
            tf.keras.layers.Dense(NUM_CLASSES, activation='softmax')
        ])
elif arch == "CNN":
    model = tf.keras.models.Sequential([
        # 1. Original flat input: (TIME_STEPS * DIMENSION)
        tf.keras.layers.InputLayer(input_shape=(TIME_STEPS * DIMENSION, )),
            
        # 2. Key reshape: transforms data into (TIME_STEPS = )8 time steps (the frames).
        # Each frame contains all x,y coordinates of your points (DIMENSION)
        tf.keras.layers.Reshape((TIME_STEPS, DIMENSION)), 
        tf.keras.layers.Dropout(0.2),
            
        # 3. First Conv1D block: analyzes relationships between points within the same frame
        # and across adjacent frames (temporal window of 3 frames)
        tf.keras.layers.Conv1D(filters=32, kernel_size=3, padding='same', activation='relu'),
        # Reduces the temporal dimension by half (from 8 frames to 4)
        tf.keras.layers.MaxPooling1D(pool_size=2),
            
        # 4. Second Conv1D block: extracts more complex movement patterns
        tf.keras.layers.Conv1D(filters=64, kernel_size=3, padding='same', activation='relu'),
        # Reduces the time dimension further (from 4 frames to 2)
        tf.keras.layers.MaxPooling1D(pool_size=2),
            
        # 5. Flattening and classification (identical to your original structure)
        tf.keras.layers.Flatten(),
        tf.keras.layers.Dropout(0.5),
        tf.keras.layers.Dense(10, activation='relu'),
        tf.keras.layers.Dense(NUM_CLASSES, activation='softmax')
    ])
else:
    # Usiamo le Functional API di Keras poiché i Transformer richiedono connessioni residue (skip connections)
    inputs = tf.keras.layers.Input(shape=(TIME_STEPS * DIMENSION, ))
    
    # 1. Reshape in (TIME_STEPS, DIMENSION)
    x = tf.keras.layers.Reshape((TIME_STEPS, DIMENSION))(inputs)
    x = tf.keras.layers.Dropout(0.2)(x)
    
    # 2. Layer di Self-Attention (il cuore del Transformer)
    # Calcola le relazioni tra i diversi frame temporali
    attention_output = tf.keras.layers.MultiHeadAttention(
        num_heads=4, key_dim=DIMENSION
    )(query=x, value=x, key=x)
    
    # 3. Connessione residua e Normalizzazione
    x = tf.keras.layers.Add()([x, attention_output])
    x = tf.keras.layers.LayerNormalization()(x)
    
    # 4. Riduzione della dimensionalità e classificazione
    x = tf.keras.layers.Flatten()(x)
    x = tf.keras.layers.Dropout(0.5)(x)
    x = tf.keras.layers.Dense(10, activation='relu')(x)
    outputs = tf.keras.layers.Dense(NUM_CLASSES, activation='softmax')(x)
    
    model = tf.keras.models.Model(inputs=inputs, outputs=outputs)

# %%
model.summary()  # tf.keras.utils.plot_model(model, show_shapes=True)
# Out:
# Model: "functional"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                  ┃ Output Shape              ┃         Param # ┃ Connected to               ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━━┩
# │ input_layer (InputLayer)      │ (None, 80)                │               0 │ -                          │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ reshape (Reshape)             │ (None, 8, 10)             │               0 │ input_layer[0][0]          │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ dropout (Dropout)             │ (None, 8, 10)             │               0 │ reshape[0][0]              │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ multi_head_attention          │ (None, 8, 10)             │           1,730 │ dropout[0][0],             │
# │ (MultiHeadAttention)          │                           │                 │ dropout[0][0],             │
# │                               │                           │                 │ dropout[0][0]              │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ add (Add)                     │ (None, 8, 10)             │               0 │ dropout[0][0],             │
# │                               │                           │                 │ multi_head_attention[0][0] │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ layer_normalization           │ (None, 8, 10)             │              20 │ add[0][0]                  │
# │ (LayerNormalization)          │                           │                 │                            │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ flatten (Flatten)             │ (None, 80)                │               0 │ layer_normalization[0][0]  │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ dropout_2 (Dropout)           │ (None, 80)                │               0 │ flatten[0][0]              │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ dense (Dense)                 │ (None, 10)                │             810 │ dropout_2[0][0]            │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ dense_1 (Dense)               │ (None, 5)                 │              55 │ dense[0][0]                │
# └───────────────────────────────┴───────────────────────────┴─────────────────┴────────────────────────────┘
#  Total params: 2,615 (10.21 KB)
#  Trainable params: 2,615 (10.21 KB)
#  Non-trainable params: 0 (0.00 B)

# %%
# モデルチェックポイントのコールバック
cp_callback = tf.keras.callbacks.ModelCheckpoint(
    model_save_path, verbose=1, save_weights_only=False)
# 早期打ち切り用コールバック
es_callback = tf.keras.callbacks.EarlyStopping(patience=20, verbose=1)

# %%
# モデルコンパイル
model.compile(
    optimizer='adam',
    loss='sparse_categorical_crossentropy',
    metrics=['accuracy']
)
# Out:
# WARNING:tensorflow:TensorFlow GPU support is not available on native Windows for TensorFlow >= 2.11. Even if CUDA/cuDNN are installed, GPU will not be used. Please use WSL2 or the TensorFlow-DirectML plugin.

# %% [markdown]
# # モデル訓練

# %%
model.fit(
    X_train,
    y_train,
    epochs=1000,
    batch_size=128,
    validation_data=(X_test, y_test), # (see above) 25% of data is used for validation
    callbacks=[cp_callback, es_callback]
)
# Out:
# Epoch 1/1000
# 1/2 ━━━━━━━━━━━━━━━━━━━━ 2s 3s/step - accuracy: 0.2188 - loss: 2.4080
# Epoch 1: saving model to model/point_history_classifier/point_history_classifier.keras
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 4s 564ms/step - accuracy: 0.2299 - loss: 2.3829 - val_accuracy: 0.1905 - val_loss: 2.1072
# Epoch 2/1000
# 1/2 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step - accuracy: 0.2500 - loss: 2.1628
# Epoch 2: saving model to model/point_history_classifier/point_history_classifier.keras
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 207ms/step - accuracy: 0.2513 - loss: 2.0876 - val_accuracy: 0.1746 - val_loss: 2.0051
# Epoch 3/1000
# 1/2 ━━━━━━━━━━━━━━━━━━━━ 0s 66ms/step - accuracy: 0.2344 - loss: 2.2098
# Epoch 3: saving model to model/point_history_classifier/point_history_classifier.keras
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 205ms/step - accuracy: 0.2032 - loss: 2.2694 - val_accuracy: 0.1429 - val_loss: 1.9197
# Epoch 4/1000
# 1/2 ━━━━━━━━━━━━━━━━━━━━ 0s 64ms/step - accuracy: 0.3125 - loss: 1.9567
# Epoch 4: saving model to model/point_history_classifier/point_history_classifier.keras
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 192ms/step - accuracy: 0.2995 - loss: 2.0129 - val_accuracy: 0.1429 - val_loss: 1.8630
# Epoch 5/1000
# 1/2 ━━━━━━━━━━━━━━━━━━━━ 0s 63ms/step - accuracy: 0.2266 - loss: 1.9495
# Epoch 5: saving model to model/point_history_classifier/point_history_classifier.keras
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 192ms/step - accuracy: 0.2620 - loss: 1.9064 - val_accuracy: 0.1746 - val_loss: 1.8188
# Epoch 6/1000
# 1/2 ━━━━━━━━━━━━━━━━━━━━ 0s 64ms/step - accuracy: 0.2500 - loss: 1.9012
# Epoch 6: saving model to model/point_history_classifier/point_history_classifier.keras
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 191ms/step - accuracy: 0.2406 - loss: 1.8950 - val_accuracy: 0.1905 - val_loss: 1.7858
# Epoch 7/1000
# 1/2 ━━━━━━━━━━━━━━━━━━━━ 0s 79ms/step - accuracy: 0.2422 - loss: 1.9876
# Epoch 7: saving model to model/point_history_classifier/point_history_classifier.keras
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 191ms/step - accuracy: 0.2620 - loss: 1.9353 - val_accuracy: 0.2540 - val_loss: 1.7555
# Epoch 8/1000
# 1/2 ━━━━━━━━━━━━━━━━━━━━ 0s 64ms/step - accuracy: 0.2422 - loss: 1.9525
# Epoch 8: saving model to model/point_history_classifier/point_history_classifier.keras
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 193ms/step - accuracy: 0.2460 - loss: 1.9284 - val_accuracy: 0.2698 - val_loss: 1.7262
# Epoch 9/1000
# 1/2 ━━━━━━━━━━━━━━━━━━━━ 0s 74ms/step - accuracy: 0.2734 - loss: 1.7073
# Epoch 9: saving model to model/point_history_classifier/point_history_classifier.keras
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 192ms/step - accuracy: 0.2727 - loss: 1.7489 - val_accuracy: 0.2857 - val_loss: 1.6984
# Epoch 10/1000
# 1/2 ━━━━━━━━━━━━━━━━━━━━ 0s 63ms/step - accuracy: 0.2734 - loss: 1.7843
# Epoch 10: saving model to model/point_history_classifier/point_history_classifier.keras
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 191ms/step - accuracy: 0.2834 - loss: 1.7637 - val_accuracy: 0.2698 - val_loss: 1.6718
# Epoch 11/1000
# 1/2 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step - accuracy: 0.2422 - loss: 1.8713
# Epoch 11: saving model to model/point_history_classifier/point_history_classifier.keras
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 205ms/step - accuracy: 0.2299 - loss: 1.8425 - val_accuracy: 0.2698 - val_loss: 1.6472
# Epoch 12/1000
# 1/2 ━━━━━━━━━━━━━━━━━━━━ 0s 58ms/step - accuracy: 0.2656 - loss: 1.8069
# Epoch 12: saving model to model/point_history_classifier/point_history_classifier.keras
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 196ms/step - accuracy: 0.2781 - loss: 1.7849 - val_accuracy: 0.3016 - val_loss: 1.6241
# Epoch 13/1000
# 1/2 ━━━━━━━━━━━━━━━━━━━━ 0s 64ms/step - accuracy: 0.2812 - loss: 1.6802
# Epoch 13: saving model to model/point_history_classifier/point_history_classifier.keras
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 207ms/step - accuracy: 0.2941 - loss: 1.6663 - val_accuracy: 0.3175 - val_loss: 1.6022
# Epoch 14/1000
# 1/2 ━━━━━━━━━━━━━━━━━━━━ 0s 64ms/step - accuracy: 0.2656 - loss: 1.8285
# Epoch 14: saving model to model/point_history_classifier/point_history_classifier.keras
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 191ms/step - accuracy: 0.2941 - loss: 1.7571 - val_accuracy: 0.3016 - val_loss: 1.5820
# Epoch 15/1000
# 1/2 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step - accuracy: 0.2891 - loss: 1.6961
# Epoch 15: saving model to model/point_history_classifier/point_history_classifier.keras
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 207ms/step - accuracy: 0.2888 - loss: 1.6504 - val_accuracy: 0.3492 - val_loss: 1.5638
# Epoch 16/1000
# 1/2 ━━━━━━━━━━━━━━━━━━━━ 0s 63ms/step - accuracy: 0.3281 - loss: 1.6054
# Epoch 16: saving model to model/point_history_classifier/point_history_classifier.keras
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 203ms/step - accuracy: 0.3102 - loss: 1.6100 - val_accuracy: 0.3492 - val_loss: 1.5488
# Epoch 17/1000
# 1/2 ━━━━━━━━━━━━━━━━━━━━ 0s 64ms/step - accuracy: 0.3359 - loss: 1.5867
# Epoch 17: saving model to model/point_history_classifier/point_history_classifier.keras
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 191ms/step - accuracy: 0.3155 - loss: 1.5976 - val_accuracy: 0.3333 - val_loss: 1.5348
# Epoch 18/1000
# 1/2 ━━━━━━━━━━━━━━━━━━━━ 0s 66ms/step - accuracy: 0.2734 - loss: 1.6887
# Epoch 18: saving model to model/point_history_classifier/point_history_classifier.keras
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 204ms/step - accuracy: 0.2888 - loss: 1.6428 - val_accuracy: 0.3333 - val_loss: 1.5215
# Epoch 19/1000
# 1/2 ━━━━━━━━━━━━━━━━━━━━ 0s 66ms/step - accuracy: 0.3047 - loss: 1.6841
# Epoch 19: saving model to model/point_history_classifier/point_history_classifier.keras
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 189ms/step - accuracy: 0.3155 - loss: 1.6545 - val_accuracy: 0.3333 - val_loss: 1.5091
# Epoch 20/1000
# 1/2 ━━━━━━━━━━━━━━━━━━━━ 0s 64ms/step - accuracy: 0.3438 - loss: 1.6033
# Epoch 20: saving model to model/point_history_classifier/point_history_classifier.keras
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 200ms/step - accuracy: 0.3422 - loss: 1.6164 - val_accuracy: 0.3810 - val_loss: 1.4974
# Epoch 21/1000
# 1/2 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step - accuracy: 0.2734 - loss: 1.7986
# Epoch 21: saving model to model/point_history_classifier/point_history_classifier.keras
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 207ms/step - accuracy: 0.3316 - loss: 1.6790 - val_accuracy: 0.3810 - val_loss: 1.4857
# Epoch 22/1000
# 1/2 ━━━━━━━━━━━━━━━━━━━━ 0s 66ms/step - accuracy: 0.3125 - loss: 1.6344
# Epoch 22: saving model to model/point_history_classifier/point_history_classifier.keras
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 186ms/step - accuracy: 0.3369 - loss: 1.5955 - val_accuracy: 0.3810 - val_loss: 1.4747
# Epoch 23/1000
# 1/2 ━━━━━━━━━━━━━━━━━━━━ 0s 61ms/step - accuracy: 0.3672 - loss: 1.5062
# Epoch 23: saving model to model/point_history_classifier/point_history_classifier.keras
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 196ms/step - accuracy: 0.3369 - loss: 1.5600 - val_accuracy: 0.3810 - val_loss: 1.4646
# Epoch 24/1000
# 1/2 ━━━━━━━━━━━━━━━━━━━━ 0s 59ms/step - accuracy: 0.3906 - loss: 1.5393
# Epoch 24: saving model to model/point_history_classifier/point_history_classifier.keras
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 190ms/step - accuracy: 0.3583 - loss: 1.5775 - val_accuracy: 0.3810 - val_loss: 1.4566
# Epoch 25/1000
# 1/2 ━━━━━━━━━━━━━━━━━━━━ 0s 63ms/step - accuracy: 0.2734 - loss: 1.5912
# Epoch 25: saving model to model/point_history_classifier/point_history_classifier.keras
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 191ms/step - accuracy: 0.3102 - loss: 1.5569 - val_accuracy: 0.3810 - val_loss: 1.4492
# Epoch 26/1000
# 1/2 ━━━━━━━━━━━━━━━━━━━━ 0s 63ms/step - accuracy: 0.2891 - loss: 1.5373
# Epoch 26: saving model to model/point_history_classifier/point_history_classifier.keras
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 191ms/step - accuracy: 0.2781 - loss: 1.5338 - val_accuracy: 0.3810 - val_loss: 1.4432
# Epoch 27/1000
# 1/2 ━━━━━━━━━━━━━━━━━━━━ 0s 80ms/step - accuracy: 0.3047 - loss: 1.5557
# Epoch 27: saving model to model/point_history_classifier/point_history_classifier.keras
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 191ms/step - accuracy: 0.3048 - loss: 1.5558 - val_accuracy: 0.3810 - val_loss: 1.4360
# Epoch 28/1000
# 1/2 ━━━━━━━━━━━━━━━━━━━━ 0s 62ms/step - accuracy: 0.2969 - loss: 1.5102
# Epoch 28: saving model to model/point_history_classifier/point_history_classifier.keras
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 192ms/step - accuracy: 0.3155 - loss: 1.5249 - val_accuracy: 0.3968 - val_loss: 1.4284
# Epoch 29/1000
# 1/2 ━━━━━━━━━━━━━━━━━━━━ 0s 53ms/step - accuracy: 0.3516 - loss: 1.4475
# Epoch 29: saving model to model/point_history_classifier/point_history_classifier.keras
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 201ms/step - accuracy: 0.3369 - loss: 1.4827 - val_accuracy: 0.4127 - val_loss: 1.4196
# Epoch 30/1000
# 1/2 ━━━━━━━━━━━━━━━━━━━━ 0s 69ms/step - accuracy: 0.3672 - loss: 1.5465
# Epoch 30: saving model to model/point_history_classifier/point_history_classifier.keras
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 192ms/step - accuracy: 0.3476 - loss: 1.5844 - val_accuracy: 0.4127 - val_loss: 1.4111
# Epoch 31/1000
# 1/2 ━━━━━━━━━━━━━━━━━━━━ 0s 63ms/step - accuracy: 0.3359 - loss: 1.5564
# Epoch 31: saving model to model/point_history_classifier/point_history_classifier.keras
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 196ms/step - accuracy: 0.3316 - loss: 1.5623 - val_accuracy: 0.4286 - val_loss: 1.4045
# Epoch 32/1000
# 1/2 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step - accuracy: 0.3672 - loss: 1.4745
# Epoch 32: saving model to model/point_history_classifier/point_history_classifier.keras
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 190ms/step - accuracy: 0.3529 - loss: 1.4817 - val_accuracy: 0.4286 - val_loss: 1.3970
# Epoch 33/1000
# 1/2 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step - accuracy: 0.3672 - loss: 1.5248
# Epoch 33: saving model to model/point_history_classifier/point_history_classifier.keras
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 207ms/step - accuracy: 0.3529 - loss: 1.5211 - val_accuracy: 0.4444 - val_loss: 1.3892
# Epoch 34/1000
# 1/2 ━━━━━━━━━━━━━━━━━━━━ 0s 64ms/step - accuracy: 0.3047 - loss: 1.5387
# Epoch 34: saving model to model/point_history_classifier/point_history_classifier.keras
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 192ms/step - accuracy: 0.3262 - loss: 1.4927 - val_accuracy: 0.4603 - val_loss: 1.3822
# Epoch 35/1000
# 1/2 ━━━━━━━━━━━━━━━━━━━━ 0s 53ms/step - accuracy: 0.3281 - loss: 1.4662
# Epoch 35: saving model to model/point_history_classifier/point_history_classifier.keras
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 202ms/step - accuracy: 0.3476 - loss: 1.4575 - val_accuracy: 0.4762 - val_loss: 1.3731
# Epoch 36/1000
# 1/2 ━━━━━━━━━━━━━━━━━━━━ 0s 53ms/step - accuracy: 0.3906 - loss: 1.4090
# Epoch 36: saving model to model/point_history_classifier/point_history_classifier.keras
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 191ms/step - accuracy: 0.3957 - loss: 1.3987 - val_accuracy: 0.4921 - val_loss: 1.3631
# Epoch 37/1000
# 1/2 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step - accuracy: 0.3516 - loss: 1.4563
# Epoch 37: saving model to model/point_history_classifier/point_history_classifier.keras
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 207ms/step - accuracy: 0.3209 - loss: 1.4982 - val_accuracy: 0.5079 - val_loss: 1.3533
# Epoch 38/1000
# 1/2 ━━━━━━━━━━━━━━━━━━━━ 0s 63ms/step - accuracy: 0.3359 - loss: 1.4786
# Epoch 38: saving model to model/point_history_classifier/point_history_classifier.keras
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 208ms/step - accuracy: 0.3155 - loss: 1.4832 - val_accuracy: 0.4921 - val_loss: 1.3453
# Epoch 39/1000
# 1/2 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step - accuracy: 0.3594 - loss: 1.3924
# Epoch 39: saving model to model/point_history_classifier/point_history_classifier.keras
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 204ms/step - accuracy: 0.3797 - loss: 1.4058 - val_accuracy: 0.4921 - val_loss: 1.3373
# Epoch 40/1000
# 1/2 ━━━━━━━━━━━━━━━━━━━━ 0s 63ms/step - accuracy: 0.3906 - loss: 1.3793
# Epoch 40: saving model to model/point_history_classifier/point_history_classifier.keras
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 191ms/step - accuracy: 0.3690 - loss: 1.4504 - val_accuracy: 0.4921 - val_loss: 1.3292
# Epoch 41/1000
# 1/2 ━━━━━━━━━━━━━━━━━━━━ 0s 74ms/step - accuracy: 0.3984 - loss: 1.4091
# Epoch 41: saving model to model/point_history_classifier/point_history_classifier.keras
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 196ms/step - accuracy: 0.3957 - loss: 1.3959 - val_accuracy: 0.5079 - val_loss: 1.3194
# Epoch 42/1000
# 1/2 ━━━━━━━━━━━━━━━━━━━━ 0s 64ms/step - accuracy: 0.3672 - loss: 1.4764
# Epoch 42: saving model to model/point_history_classifier/point_history_classifier.keras
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 191ms/step - accuracy: 0.3690 - loss: 1.4775 - val_accuracy: 0.5238 - val_loss: 1.3091
# Epoch 43/1000
# 1/2 ━━━━━━━━━━━━━━━━━━━━ 0s 53ms/step - accuracy: 0.3359 - loss: 1.4252
# Epoch 43: saving model to model/point_history_classifier/point_history_classifier.keras
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 191ms/step - accuracy: 0.3797 - loss: 1.4143 - val_accuracy: 0.5079 - val_loss: 1.2983
# Epoch 44/1000
# 1/2 ━━━━━━━━━━━━━━━━━━━━ 0s 63ms/step - accuracy: 0.4297 - loss: 1.3339
# Epoch 44: saving model to model/point_history_classifier/point_history_classifier.keras
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 191ms/step - accuracy: 0.3850 - loss: 1.4149 - val_accuracy: 0.5238 - val_loss: 1.2883
# Epoch 45/1000
# 1/2 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step - accuracy: 0.4062 - loss: 1.3522
# Epoch 45: saving model to model/point_history_classifier/point_history_classifier.keras
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 207ms/step - accuracy: 0.4118 - loss: 1.3427 - val_accuracy: 0.5238 - val_loss: 1.2773
# Epoch 46/1000
# 1/2 ━━━━━━━━━━━━━━━━━━━━ 0s 64ms/step - accuracy: 0.3516 - loss: 1.4009
# Epoch 46: saving model to model/point_history_classifier/point_history_classifier.keras
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 191ms/step - accuracy: 0.3904 - loss: 1.3549 - val_accuracy: 0.5238 - val_loss: 1.2663
# Epoch 47/1000
# 1/2 ━━━━━━━━━━━━━━━━━━━━ 0s 74ms/step - accuracy: 0.4688 - loss: 1.3591
# Epoch 47: saving model to model/point_history_classifier/point_history_classifier.keras
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 194ms/step - accuracy: 0.4225 - loss: 1.3961 - val_accuracy: 0.5079 - val_loss: 1.2543
# Epoch 48/1000
# 1/2 ━━━━━━━━━━━━━━━━━━━━ 0s 64ms/step - accuracy: 0.4609 - loss: 1.2864
# Epoch 48: saving model to model/point_history_classifier/point_history_classifier.keras
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 191ms/step - accuracy: 0.4332 - loss: 1.3002 - val_accuracy: 0.5397 - val_loss: 1.2418
# Epoch 49/1000
# 1/2 ━━━━━━━━━━━━━━━━━━━━ 0s 63ms/step - accuracy: 0.4062 - loss: 1.3598
# Epoch 49: saving model to model/point_history_classifier/point_history_classifier.keras
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 191ms/step - accuracy: 0.4118 - loss: 1.3455 - val_accuracy: 0.5556 - val_loss: 1.2305
# Epoch 50/1000
# 1/2 ━━━━━━━━━━━━━━━━━━━━ 0s 84ms/step - accuracy: 0.4219 - loss: 1.3182
# Epoch 50: saving model to model/point_history_classifier/point_history_classifier.keras
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 185ms/step - accuracy: 0.4439 - loss: 1.3235 - val_accuracy: 0.5556 - val_loss: 1.2191
# Epoch 51/1000
# 1/2 ━━━━━━━━━━━━━━━━━━━━ 0s 60ms/step - accuracy: 0.4297 - loss: 1.3194
# Epoch 51: saving model to model/point_history_classifier/point_history_classifier.keras
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 206ms/step - accuracy: 0.4385 - loss: 1.3206 - val_accuracy: 0.5714 - val_loss: 1.2070
# Epoch 52/1000
# 1/2 ━━━━━━━━━━━━━━━━━━━━ 0s 63ms/step - accuracy: 0.4531 - loss: 1.3357
# Epoch 52: saving model to model/point_history_classifier/point_history_classifier.keras
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 192ms/step - accuracy: 0.4706 - loss: 1.3392 - val_accuracy: 0.5714 - val_loss: 1.1949
# Epoch 53/1000
# 1/2 ━━━━━━━━━━━━━━━━━━━━ 0s 65ms/step - accuracy: 0.4453 - loss: 1.2583
# Epoch 53: saving model to model/point_history_classifier/point_history_classifier.keras
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 187ms/step - accuracy: 0.4118 - loss: 1.3226 - val_accuracy: 0.5873 - val_loss: 1.1835
# Epoch 54/1000
# 1/2 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step - accuracy: 0.4766 - loss: 1.2877
# Epoch 54: saving model to model/point_history_classifier/point_history_classifier.keras
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 207ms/step - accuracy: 0.4706 - loss: 1.2648 - val_accuracy: 0.5873 - val_loss: 1.1722
# Epoch 55/1000
# 1/2 ━━━━━━━━━━━━━━━━━━━━ 0s 59ms/step - accuracy: 0.4766 - loss: 1.2720
# Epoch 55: saving model to model/point_history_classifier/point_history_classifier.keras
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 206ms/step - accuracy: 0.4492 - loss: 1.2735 - val_accuracy: 0.5873 - val_loss: 1.1606
# Epoch 56/1000
# 1/2 ━━━━━━━━━━━━━━━━━━━━ 0s 64ms/step - accuracy: 0.5156 - loss: 1.2389
# Epoch 56: saving model to model/point_history_classifier/point_history_classifier.keras
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 201ms/step - accuracy: 0.4973 - loss: 1.2583 - val_accuracy: 0.5873 - val_loss: 1.1485
# Epoch 57/1000
# 1/2 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step - accuracy: 0.3672 - loss: 1.3284
# Epoch 57: saving model to model/point_history_classifier/point_history_classifier.keras
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 207ms/step - accuracy: 0.4064 - loss: 1.2963 - val_accuracy: 0.5873 - val_loss: 1.1374
# Epoch 58/1000
# 1/2 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step - accuracy: 0.4453 - loss: 1.2316
# Epoch 58: saving model to model/point_history_classifier/point_history_classifier.keras
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 204ms/step - accuracy: 0.4759 - loss: 1.2505 - val_accuracy: 0.6190 - val_loss: 1.1275
# Epoch 59/1000
# 1/2 ━━━━━━━━━━━━━━━━━━━━ 0s 74ms/step - accuracy: 0.4453 - loss: 1.2362
# Epoch 59: saving model to model/point_history_classifier/point_history_classifier.keras
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 197ms/step - accuracy: 0.4652 - loss: 1.2071 - val_accuracy: 0.6190 - val_loss: 1.1171
# Epoch 60/1000
# 1/2 ━━━━━━━━━━━━━━━━━━━━ 0s 63ms/step - accuracy: 0.5000 - loss: 1.1806
# Epoch 60: saving model to model/point_history_classifier/point_history_classifier.keras
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 201ms/step - accuracy: 0.4920 - loss: 1.2013 - val_accuracy: 0.6032 - val_loss: 1.1055
# Epoch 61/1000
# 1/2 ━━━━━━━━━━━━━━━━━━━━ 0s 64ms/step - accuracy: 0.4453 - loss: 1.2329
# Epoch 61: saving model to model/point_history_classifier/point_history_classifier.keras
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 205ms/step - accuracy: 0.4011 - loss: 1.2821 - val_accuracy: 0.6190 - val_loss: 1.0941
# Epoch 62/1000
# 1/2 ━━━━━━━━━━━━━━━━━━━━ 0s 64ms/step - accuracy: 0.4531 - loss: 1.2504
# Epoch 62: saving model to model/point_history_classifier/point_history_classifier.keras
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 207ms/step - accuracy: 0.4813 - loss: 1.2226 - val_accuracy: 0.6190 - val_loss: 1.0819
# Epoch 63/1000
# 1/2 ━━━━━━━━━━━━━━━━━━━━ 0s 58ms/step - accuracy: 0.4375 - loss: 1.2714
# Epoch 63: saving model to model/point_history_classifier/point_history_classifier.keras
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 191ms/step - accuracy: 0.4332 - loss: 1.2627 - val_accuracy: 0.6349 - val_loss: 1.0697
# Epoch 64/1000
# 1/2 ━━━━━━━━━━━━━━━━━━━━ 0s 63ms/step - accuracy: 0.4141 - loss: 1.2782
# Epoch 64: saving model to model/point_history_classifier/point_history_classifier.keras
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 191ms/step - accuracy: 0.4332 - loss: 1.2687 - val_accuracy: 0.6349 - val_loss: 1.0573
# Epoch 65/1000
# 1/2 ━━━━━━━━━━━━━━━━━━━━ 0s 63ms/step - accuracy: 0.4766 - loss: 1.2333
# Epoch 65: saving model to model/point_history_classifier/point_history_classifier.keras
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 207ms/step - accuracy: 0.4920 - loss: 1.2247 - val_accuracy: 0.6349 - val_loss: 1.0455
# Epoch 66/1000
# 1/2 ━━━━━━━━━━━━━━━━━━━━ 0s 64ms/step - accuracy: 0.4844 - loss: 1.1791
# Epoch 66: saving model to model/point_history_classifier/point_history_classifier.keras
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 188ms/step - accuracy: 0.5134 - loss: 1.1538 - val_accuracy: 0.6508 - val_loss: 1.0329
# Epoch 67/1000
# 1/2 ━━━━━━━━━━━━━━━━━━━━ 0s 63ms/step - accuracy: 0.5000 - loss: 1.2130
# Epoch 67: saving model to model/point_history_classifier/point_history_classifier.keras
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 203ms/step - accuracy: 0.5241 - loss: 1.1846 - val_accuracy: 0.6984 - val_loss: 1.0197
# Epoch 68/1000
# 1/2 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step - accuracy: 0.5312 - loss: 1.1721
# Epoch 68: saving model to model/point_history_classifier/point_history_classifier.keras
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 208ms/step - accuracy: 0.5027 - loss: 1.1659 - val_accuracy: 0.7302 - val_loss: 1.0069
# Epoch 69/1000
# 1/2 ━━━━━━━━━━━━━━━━━━━━ 0s 64ms/step - accuracy: 0.5156 - loss: 1.1973
# Epoch 69: saving model to model/point_history_classifier/point_history_classifier.keras
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 191ms/step - accuracy: 0.4866 - loss: 1.2020 - val_accuracy: 0.7143 - val_loss: 0.9952
# Epoch 70/1000
# 1/2 ━━━━━━━━━━━━━━━━━━━━ 0s 60ms/step - accuracy: 0.5078 - loss: 1.1128
# Epoch 70: saving model to model/point_history_classifier/point_history_classifier.keras
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 207ms/step - accuracy: 0.5080 - loss: 1.1483 - val_accuracy: 0.7143 - val_loss: 0.9838
# Epoch 71/1000
# 1/2 ━━━━━━━━━━━━━━━━━━━━ 0s 63ms/step - accuracy: 0.5547 - loss: 1.1180
# Epoch 71: saving model to model/point_history_classifier/point_history_classifier.keras
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 191ms/step - accuracy: 0.5615 - loss: 1.1148 - val_accuracy: 0.7143 - val_loss: 0.9735
# Epoch 72/1000
# 1/2 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step - accuracy: 0.5859 - loss: 1.0378
# Epoch 72: saving model to model/point_history_classifier/point_history_classifier.keras
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 209ms/step - accuracy: 0.5401 - loss: 1.1252 - val_accuracy: 0.7143 - val_loss: 0.9626
# Epoch 73/1000
# 1/2 ━━━━━━━━━━━━━━━━━━━━ 0s 58ms/step - accuracy: 0.4766 - loss: 1.2036
# Epoch 73: saving model to model/point_history_classifier/point_history_classifier.keras
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 199ms/step - accuracy: 0.5027 - loss: 1.1733 - val_accuracy: 0.6984 - val_loss: 0.9535
# Epoch 74/1000
# 1/2 ━━━━━━━━━━━━━━━━━━━━ 0s 59ms/step - accuracy: 0.5625 - loss: 1.0681
# Epoch 74: saving model to model/point_history_classifier/point_history_classifier.keras
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 196ms/step - accuracy: 0.5348 - loss: 1.0993 - val_accuracy: 0.6825 - val_loss: 0.9451
# Epoch 75/1000
# 1/2 ━━━━━━━━━━━━━━━━━━━━ 0s 64ms/step - accuracy: 0.5391 - loss: 1.0406
# Epoch 75: saving model to model/point_history_classifier/point_history_classifier.keras
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 192ms/step - accuracy: 0.5455 - loss: 1.0864 - val_accuracy: 0.6825 - val_loss: 0.9358
# Epoch 76/1000
# 1/2 ━━━━━━━━━━━━━━━━━━━━ 0s 64ms/step - accuracy: 0.5703 - loss: 1.0596
# Epoch 76: saving model to model/point_history_classifier/point_history_classifier.keras
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 190ms/step - accuracy: 0.5241 - loss: 1.0837 - val_accuracy: 0.6825 - val_loss: 0.9277
# Epoch 77/1000
# 1/2 ━━━━━━━━━━━━━━━━━━━━ 0s 79ms/step - accuracy: 0.6250 - loss: 0.9924
# Epoch 77: saving model to model/point_history_classifier/point_history_classifier.keras
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 223ms/step - accuracy: 0.6043 - loss: 1.0303 - val_accuracy: 0.6984 - val_loss: 0.9192
# Epoch 78/1000
# 1/2 ━━━━━━━━━━━━━━━━━━━━ 0s 64ms/step - accuracy: 0.5938 - loss: 0.9549
# Epoch 78: saving model to model/point_history_classifier/point_history_classifier.keras
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 208ms/step - accuracy: 0.6150 - loss: 0.9832 - val_accuracy: 0.6984 - val_loss: 0.9102
# Epoch 79/1000
# 1/2 ━━━━━━━━━━━━━━━━━━━━ 0s 79ms/step - accuracy: 0.5938 - loss: 0.9861
# Epoch 79: saving model to model/point_history_classifier/point_history_classifier.keras
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 224ms/step - accuracy: 0.5936 - loss: 1.0085 - val_accuracy: 0.6984 - val_loss: 0.9015
# Epoch 80/1000
# 1/2 ━━━━━━━━━━━━━━━━━━━━ 0s 63ms/step - accuracy: 0.5859 - loss: 1.0117
# Epoch 80: saving model to model/point_history_classifier/point_history_classifier.keras
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 192ms/step - accuracy: 0.5882 - loss: 1.0129 - val_accuracy: 0.6984 - val_loss: 0.8918
# Epoch 81/1000
# 1/2 ━━━━━━━━━━━━━━━━━━━━ 0s 72ms/step - accuracy: 0.5859 - loss: 1.0236
# Epoch 81: saving model to model/point_history_classifier/point_history_classifier.keras
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 192ms/step - accuracy: 0.5455 - loss: 1.0405 - val_accuracy: 0.6984 - val_loss: 0.8812
# Epoch 82/1000
# 1/2 ━━━━━━━━━━━━━━━━━━━━ 0s 63ms/step - accuracy: 0.5312 - loss: 1.0373
# Epoch 82: saving model to model/point_history_classifier/point_history_classifier.keras
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 191ms/step - accuracy: 0.5829 - loss: 0.9907 - val_accuracy: 0.6984 - val_loss: 0.8684
# Epoch 83/1000
# 1/2 ━━━━━━━━━━━━━━━━━━━━ 0s 64ms/step - accuracy: 0.5703 - loss: 0.9902
# Epoch 83: saving model to model/point_history_classifier/point_history_classifier.keras
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 191ms/step - accuracy: 0.5936 - loss: 0.9802 - val_accuracy: 0.6984 - val_loss: 0.8556
# Epoch 84/1000
# 1/2 ━━━━━━━━━━━━━━━━━━━━ 0s 63ms/step - accuracy: 0.5703 - loss: 0.9791
# Epoch 84: saving model to model/point_history_classifier/point_history_classifier.keras
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 192ms/step - accuracy: 0.6096 - loss: 0.9570 - val_accuracy: 0.6825 - val_loss: 0.8436
# Epoch 85/1000
# 1/2 ━━━━━━━━━━━━━━━━━━━━ 0s 61ms/step - accuracy: 0.5391 - loss: 1.0243
# Epoch 85: saving model to model/point_history_classifier/point_history_classifier.keras
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 202ms/step - accuracy: 0.5241 - loss: 1.0508 - val_accuracy: 0.6825 - val_loss: 0.8323
# Epoch 86/1000
# 1/2 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step - accuracy: 0.6016 - loss: 1.0044
# Epoch 86: saving model to model/point_history_classifier/point_history_classifier.keras
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 223ms/step - accuracy: 0.5775 - loss: 1.0098 - val_accuracy: 0.6984 - val_loss: 0.8207
# Epoch 87/1000
# 1/2 ━━━━━━━━━━━━━━━━━━━━ 0s 63ms/step - accuracy: 0.6172 - loss: 0.9210
# Epoch 87: saving model to model/point_history_classifier/point_history_classifier.keras
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 201ms/step - accuracy: 0.6043 - loss: 0.9314 - val_accuracy: 0.6984 - val_loss: 0.8094
# Epoch 88/1000
# 1/2 ━━━━━━━━━━━━━━━━━━━━ 0s 54ms/step - accuracy: 0.6016 - loss: 0.9665
# Epoch 88: saving model to model/point_history_classifier/point_history_classifier.keras
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 208ms/step - accuracy: 0.6096 - loss: 0.9702 - val_accuracy: 0.6984 - val_loss: 0.7994
# Epoch 89/1000
# 1/2 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step - accuracy: 0.5703 - loss: 1.0182
# Epoch 89: saving model to model/point_history_classifier/point_history_classifier.keras
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 208ms/step - accuracy: 0.6203 - loss: 0.9494 - val_accuracy: 0.6984 - val_loss: 0.7885
# Epoch 90/1000
# 1/2 ━━━━━━━━━━━━━━━━━━━━ 0s 64ms/step - accuracy: 0.5859 - loss: 0.8781
# Epoch 90: saving model to model/point_history_classifier/point_history_classifier.keras
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 190ms/step - accuracy: 0.5615 - loss: 0.9518 - val_accuracy: 0.6984 - val_loss: 0.7773
# Epoch 91/1000
# 1/2 ━━━━━━━━━━━━━━━━━━━━ 0s 64ms/step - accuracy: 0.5547 - loss: 0.9324
# Epoch 91: saving model to model/point_history_classifier/point_history_classifier.keras
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 191ms/step - accuracy: 0.5882 - loss: 0.8833 - val_accuracy: 0.7143 - val_loss: 0.7657
# Epoch 92/1000
# 1/2 ━━━━━━━━━━━━━━━━━━━━ 0s 54ms/step - accuracy: 0.6953 - loss: 0.8797
# Epoch 92: saving model to model/point_history_classifier/point_history_classifier.keras
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 209ms/step - accuracy: 0.6631 - loss: 0.9091 - val_accuracy: 0.6984 - val_loss: 0.7547
# Epoch 93/1000
# 1/2 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step - accuracy: 0.6016 - loss: 0.8595
# Epoch 93: saving model to model/point_history_classifier/point_history_classifier.keras
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 222ms/step - accuracy: 0.5882 - loss: 0.8967 - val_accuracy: 0.7143 - val_loss: 0.7457
# Epoch 94/1000
# 1/2 ━━━━━━━━━━━━━━━━━━━━ 0s 63ms/step - accuracy: 0.5859 - loss: 0.9192
# Epoch 94: saving model to model/point_history_classifier/point_history_classifier.keras
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 190ms/step - accuracy: 0.6043 - loss: 0.9195 - val_accuracy: 0.7143 - val_loss: 0.7363
# Epoch 95/1000
# 1/2 ━━━━━━━━━━━━━━━━━━━━ 0s 54ms/step - accuracy: 0.6250 - loss: 0.8946
# Epoch 95: saving model to model/point_history_classifier/point_history_classifier.keras
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 206ms/step - accuracy: 0.6096 - loss: 0.9145 - val_accuracy: 0.7143 - val_loss: 0.7280
# Epoch 96/1000
# 1/2 ━━━━━━━━━━━━━━━━━━━━ 0s 63ms/step - accuracy: 0.6328 - loss: 0.9222
# Epoch 96: saving model to model/point_history_classifier/point_history_classifier.keras
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 193ms/step - accuracy: 0.6364 - loss: 0.9310 - val_accuracy: 0.7460 - val_loss: 0.7202
# Epoch 97/1000
# 1/2 ━━━━━━━━━━━━━━━━━━━━ 0s 64ms/step - accuracy: 0.6094 - loss: 0.9384
# Epoch 97: saving model to model/point_history_classifier/point_history_classifier.keras
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 191ms/step - accuracy: 0.6310 - loss: 0.8966 - val_accuracy: 0.7460 - val_loss: 0.7122
# Epoch 98/1000
# 1/2 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step - accuracy: 0.6719 - loss: 0.8108
# Epoch 98: saving model to model/point_history_classifier/point_history_classifier.keras
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 208ms/step - accuracy: 0.6471 - loss: 0.8357 - val_accuracy: 0.7460 - val_loss: 0.7050
# Epoch 99/1000
# 1/2 ━━━━━━━━━━━━━━━━━━━━ 0s 62ms/step - accuracy: 0.6172 - loss: 0.8720
# Epoch 99: saving model to model/point_history_classifier/point_history_classifier.keras
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 206ms/step - accuracy: 0.6203 - loss: 0.8507 - val_accuracy: 0.7460 - val_loss: 0.6986
# Epoch 100/1000
# 1/2 ━━━━━━━━━━━━━━━━━━━━ 0s 73ms/step - accuracy: 0.6797 - loss: 0.8410
# Epoch 100: saving model to model/point_history_classifier/point_history_classifier.keras
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 194ms/step - accuracy: 0.6898 - loss: 0.7663 - val_accuracy: 0.7302 - val_loss: 0.6930
# Epoch 101/1000
# 1/2 ━━━━━━━━━━━━━━━━━━━━ 0s 64ms/step - accuracy: 0.6406 - loss: 0.8602
# Epoch 101: saving model to model/point_history_classifier/point_history_classifier.keras
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 207ms/step - accuracy: 0.6257 - loss: 0.8774 - val_accuracy: 0.7619 - val_loss: 0.6870
# Epoch 102/1000
# 1/2 ━━━━━━━━━━━━━━━━━━━━ 0s 63ms/step - accuracy: 0.6328 - loss: 0.7879
# Epoch 102: saving model to model/point_history_classifier/point_history_classifier.keras
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 207ms/step - accuracy: 0.6150 - loss: 0.8409 - val_accuracy: 0.7619 - val_loss: 0.6805
# Epoch 103/1000
# 1/2 ━━━━━━━━━━━━━━━━━━━━ 0s 63ms/step - accuracy: 0.6719 - loss: 0.8164
# Epoch 103: saving model to model/point_history_classifier/point_history_classifier.keras
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 200ms/step - accuracy: 0.6845 - loss: 0.8020 - val_accuracy: 0.7619 - val_loss: 0.6728
# Epoch 104/1000
# 1/2 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step - accuracy: 0.6719 - loss: 0.7704
# Epoch 104: saving model to model/point_history_classifier/point_history_classifier.keras
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 207ms/step - accuracy: 0.6524 - loss: 0.7865 - val_accuracy: 0.7460 - val_loss: 0.6662
# Epoch 105/1000
# 1/2 ━━━━━━━━━━━━━━━━━━━━ 0s 64ms/step - accuracy: 0.6484 - loss: 0.8235
# Epoch 105: saving model to model/point_history_classifier/point_history_classifier.keras
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 200ms/step - accuracy: 0.6417 - loss: 0.8117 - val_accuracy: 0.7460 - val_loss: 0.6604
# Epoch 106/1000
# 1/2 ━━━━━━━━━━━━━━━━━━━━ 0s 71ms/step - accuracy: 0.7109 - loss: 0.7344
# Epoch 106: saving model to model/point_history_classifier/point_history_classifier.keras
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 192ms/step - accuracy: 0.6631 - loss: 0.7847 - val_accuracy: 0.7619 - val_loss: 0.6550
# Epoch 107/1000
# 1/2 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step - accuracy: 0.5703 - loss: 0.8778
# Epoch 107: saving model to model/point_history_classifier/point_history_classifier.keras
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 204ms/step - accuracy: 0.5829 - loss: 0.8825 - val_accuracy: 0.7619 - val_loss: 0.6491
# Epoch 108/1000
# 1/2 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step - accuracy: 0.6484 - loss: 0.8032
# Epoch 108: saving model to model/point_history_classifier/point_history_classifier.keras
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 190ms/step - accuracy: 0.6364 - loss: 0.8594 - val_accuracy: 0.7619 - val_loss: 0.6433
# Epoch 109/1000
# 1/2 ━━━━━━━━━━━━━━━━━━━━ 0s 53ms/step - accuracy: 0.7266 - loss: 0.7365
# Epoch 109: saving model to model/point_history_classifier/point_history_classifier.keras
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 192ms/step - accuracy: 0.6791 - loss: 0.7864 - val_accuracy: 0.7619 - val_loss: 0.6387
# Epoch 110/1000
# 1/2 ━━━━━━━━━━━━━━━━━━━━ 0s 53ms/step - accuracy: 0.6641 - loss: 0.7948
# Epoch 110: saving model to model/point_history_classifier/point_history_classifier.keras
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 202ms/step - accuracy: 0.6471 - loss: 0.8044 - val_accuracy: 0.7619 - val_loss: 0.6352
# Epoch 111/1000
# 1/2 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step - accuracy: 0.6484 - loss: 0.8046
# Epoch 111: saving model to model/point_history_classifier/point_history_classifier.keras
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 220ms/step - accuracy: 0.6364 - loss: 0.8190 - val_accuracy: 0.7460 - val_loss: 0.6305
# Epoch 112/1000
# 1/2 ━━━━━━━━━━━━━━━━━━━━ 0s 79ms/step - accuracy: 0.6719 - loss: 0.7489
# Epoch 112: saving model to model/point_history_classifier/point_history_classifier.keras
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 191ms/step - accuracy: 0.6631 - loss: 0.7734 - val_accuracy: 0.7619 - val_loss: 0.6256
# Epoch 113/1000
# 1/2 ━━━━━━━━━━━━━━━━━━━━ 0s 63ms/step - accuracy: 0.6172 - loss: 0.8149
# Epoch 113: saving model to model/point_history_classifier/point_history_classifier.keras
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 192ms/step - accuracy: 0.6364 - loss: 0.8036 - val_accuracy: 0.7619 - val_loss: 0.6193
# Epoch 114/1000
# 1/2 ━━━━━━━━━━━━━━━━━━━━ 0s 63ms/step - accuracy: 0.6953 - loss: 0.7688
# Epoch 114: saving model to model/point_history_classifier/point_history_classifier.keras
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 202ms/step - accuracy: 0.6952 - loss: 0.8013 - val_accuracy: 0.7619 - val_loss: 0.6123
# Epoch 115/1000
# 1/2 ━━━━━━━━━━━━━━━━━━━━ 0s 54ms/step - accuracy: 0.7031 - loss: 0.6928
# Epoch 115: saving model to model/point_history_classifier/point_history_classifier.keras
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 219ms/step - accuracy: 0.7005 - loss: 0.7179 - val_accuracy: 0.7619 - val_loss: 0.6051
# Epoch 116/1000
# 1/2 ━━━━━━━━━━━━━━━━━━━━ 0s 53ms/step - accuracy: 0.7188 - loss: 0.7317
# Epoch 116: saving model to model/point_history_classifier/point_history_classifier.keras
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 204ms/step - accuracy: 0.7166 - loss: 0.7528 - val_accuracy: 0.7619 - val_loss: 0.5992
# Epoch 117/1000
# 1/2 ━━━━━━━━━━━━━━━━━━━━ 0s 115ms/step - accuracy: 0.6094 - loss: 0.7992
# Epoch 117: saving model to model/point_history_classifier/point_history_classifier.keras
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 192ms/step - accuracy: 0.6524 - loss: 0.7521 - val_accuracy: 0.7619 - val_loss: 0.5953
# Epoch 118/1000
# 1/2 ━━━━━━━━━━━━━━━━━━━━ 0s 63ms/step - accuracy: 0.7031 - loss: 0.7368
# Epoch 118: saving model to model/point_history_classifier/point_history_classifier.keras
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 199ms/step - accuracy: 0.6952 - loss: 0.7125 - val_accuracy: 0.7619 - val_loss: 0.5900
# Epoch 119/1000
# 1/2 ━━━━━━━━━━━━━━━━━━━━ 0s 58ms/step - accuracy: 0.7734 - loss: 0.6650
# Epoch 119: saving model to model/point_history_classifier/point_history_classifier.keras
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 196ms/step - accuracy: 0.7540 - loss: 0.6759 - val_accuracy: 0.7619 - val_loss: 0.5840
# Epoch 120/1000
# 1/2 ━━━━━━━━━━━━━━━━━━━━ 0s 63ms/step - accuracy: 0.6953 - loss: 0.8257
# Epoch 120: saving model to model/point_history_classifier/point_history_classifier.keras
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 197ms/step - accuracy: 0.6952 - loss: 0.7651 - val_accuracy: 0.7778 - val_loss: 0.5793
# Epoch 121/1000
# 1/2 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step - accuracy: 0.7656 - loss: 0.6789
# Epoch 121: saving model to model/point_history_classifier/point_history_classifier.keras
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 191ms/step - accuracy: 0.7754 - loss: 0.6628 - val_accuracy: 0.7619 - val_loss: 0.5741
# Epoch 122/1000
# 1/2 ━━━━━━━━━━━━━━━━━━━━ 0s 64ms/step - accuracy: 0.6875 - loss: 0.7139
# Epoch 122: saving model to model/point_history_classifier/point_history_classifier.keras
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 207ms/step - accuracy: 0.7166 - loss: 0.6840 - val_accuracy: 0.7778 - val_loss: 0.5686
# Epoch 123/1000
# 1/2 ━━━━━━━━━━━━━━━━━━━━ 0s 63ms/step - accuracy: 0.6562 - loss: 0.7022
# Epoch 123: saving model to model/point_history_classifier/point_history_classifier.keras
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 189ms/step - accuracy: 0.6524 - loss: 0.7051 - val_accuracy: 0.7937 - val_loss: 0.5622
# Epoch 124/1000
# 1/2 ━━━━━━━━━━━━━━━━━━━━ 0s 64ms/step - accuracy: 0.5781 - loss: 0.7910
# Epoch 124: saving model to model/point_history_classifier/point_history_classifier.keras
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 190ms/step - accuracy: 0.6524 - loss: 0.7473 - val_accuracy: 0.7937 - val_loss: 0.5564
# Epoch 125/1000
# 1/2 ━━━━━━━━━━━━━━━━━━━━ 0s 64ms/step - accuracy: 0.7188 - loss: 0.7015
# Epoch 125: saving model to model/point_history_classifier/point_history_classifier.keras
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 192ms/step - accuracy: 0.7005 - loss: 0.7227 - val_accuracy: 0.7937 - val_loss: 0.5521
# Epoch 126/1000
# 1/2 ━━━━━━━━━━━━━━━━━━━━ 0s 64ms/step - accuracy: 0.7344 - loss: 0.6946
# Epoch 126: saving model to model/point_history_classifier/point_history_classifier.keras
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 199ms/step - accuracy: 0.7326 - loss: 0.6849 - val_accuracy: 0.7937 - val_loss: 0.5496
# Epoch 127/1000
# 1/2 ━━━━━━━━━━━━━━━━━━━━ 0s 64ms/step - accuracy: 0.6562 - loss: 0.7071
# Epoch 127: saving model to model/point_history_classifier/point_history_classifier.keras
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 206ms/step - accuracy: 0.6738 - loss: 0.7030 - val_accuracy: 0.7937 - val_loss: 0.5501
# Epoch 128/1000
# 1/2 ━━━━━━━━━━━━━━━━━━━━ 0s 63ms/step - accuracy: 0.7422 - loss: 0.6819
# Epoch 128: saving model to model/point_history_classifier/point_history_classifier.keras
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 192ms/step - accuracy: 0.7219 - loss: 0.7151 - val_accuracy: 0.7937 - val_loss: 0.5516
# Epoch 129/1000
# 1/2 ━━━━━━━━━━━━━━━━━━━━ 0s 64ms/step - accuracy: 0.7109 - loss: 0.6234
# Epoch 129: saving model to model/point_history_classifier/point_history_classifier.keras
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 190ms/step - accuracy: 0.7005 - loss: 0.6259 - val_accuracy: 0.7937 - val_loss: 0.5500
# Epoch 130/1000
# 1/2 ━━━━━━━━━━━━━━━━━━━━ 0s 76ms/step - accuracy: 0.7344 - loss: 0.6862
# Epoch 130: saving model to model/point_history_classifier/point_history_classifier.keras
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 192ms/step - accuracy: 0.7219 - loss: 0.6523 - val_accuracy: 0.8095 - val_loss: 0.5422
# Epoch 131/1000
# 1/2 ━━━━━━━━━━━━━━━━━━━━ 0s 64ms/step - accuracy: 0.7500 - loss: 0.5910
# Epoch 131: saving model to model/point_history_classifier/point_history_classifier.keras
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 190ms/step - accuracy: 0.7326 - loss: 0.5910 - val_accuracy: 0.7937 - val_loss: 0.5324
# Epoch 132/1000
# 1/2 ━━━━━━━━━━━━━━━━━━━━ 0s 64ms/step - accuracy: 0.7422 - loss: 0.6994
# Epoch 132: saving model to model/point_history_classifier/point_history_classifier.keras
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 208ms/step - accuracy: 0.7540 - loss: 0.6433 - val_accuracy: 0.7937 - val_loss: 0.5252
# Epoch 133/1000
# 1/2 ━━━━━━━━━━━━━━━━━━━━ 0s 64ms/step - accuracy: 0.7188 - loss: 0.6575
# Epoch 133: saving model to model/point_history_classifier/point_history_classifier.keras
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 199ms/step - accuracy: 0.7219 - loss: 0.6665 - val_accuracy: 0.7937 - val_loss: 0.5191
# Epoch 134/1000
# 1/2 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step - accuracy: 0.7656 - loss: 0.5890
# Epoch 134: saving model to model/point_history_classifier/point_history_classifier.keras
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 192ms/step - accuracy: 0.7487 - loss: 0.6184 - val_accuracy: 0.7778 - val_loss: 0.5148
# Epoch 135/1000
# 1/2 ━━━━━━━━━━━━━━━━━━━━ 0s 63ms/step - accuracy: 0.7344 - loss: 0.6448
# Epoch 135: saving model to model/point_history_classifier/point_history_classifier.keras
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 202ms/step - accuracy: 0.7326 - loss: 0.6409 - val_accuracy: 0.7937 - val_loss: 0.5118
# Epoch 136/1000
# 1/2 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step - accuracy: 0.7578 - loss: 0.5448
# Epoch 136: saving model to model/point_history_classifier/point_history_classifier.keras
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 220ms/step - accuracy: 0.7326 - loss: 0.5794 - val_accuracy: 0.7937 - val_loss: 0.5093
# Epoch 137/1000
# 1/2 ━━━━━━━━━━━━━━━━━━━━ 0s 64ms/step - accuracy: 0.7422 - loss: 0.6075
# Epoch 137: saving model to model/point_history_classifier/point_history_classifier.keras
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 203ms/step - accuracy: 0.7112 - loss: 0.6208 - val_accuracy: 0.7937 - val_loss: 0.5052
# Epoch 138/1000
# 1/2 ━━━━━━━━━━━━━━━━━━━━ 0s 63ms/step - accuracy: 0.7422 - loss: 0.6008
# Epoch 138: saving model to model/point_history_classifier/point_history_classifier.keras
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 207ms/step - accuracy: 0.7487 - loss: 0.6126 - val_accuracy: 0.7937 - val_loss: 0.5004
# Epoch 139/1000
# 1/2 ━━━━━━━━━━━━━━━━━━━━ 0s 63ms/step - accuracy: 0.7344 - loss: 0.6341
# Epoch 139: saving model to model/point_history_classifier/point_history_classifier.keras
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 213ms/step - accuracy: 0.7380 - loss: 0.6204 - val_accuracy: 0.7937 - val_loss: 0.4941
# Epoch 140/1000
# 1/2 ━━━━━━━━━━━━━━━━━━━━ 0s 69ms/step - accuracy: 0.8047 - loss: 0.5450
# Epoch 140: saving model to model/point_history_classifier/point_history_classifier.keras
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 226ms/step - accuracy: 0.7807 - loss: 0.5542 - val_accuracy: 0.7937 - val_loss: 0.4894
# Epoch 141/1000
# 1/2 ━━━━━━━━━━━━━━━━━━━━ 0s 71ms/step - accuracy: 0.6953 - loss: 0.6783
# Epoch 141: saving model to model/point_history_classifier/point_history_classifier.keras
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 250ms/step - accuracy: 0.7487 - loss: 0.6128 - val_accuracy: 0.7937 - val_loss: 0.4870
# Epoch 142/1000
# 1/2 ━━━━━━━━━━━━━━━━━━━━ 0s 64ms/step - accuracy: 0.7422 - loss: 0.6032
# Epoch 142: saving model to model/point_history_classifier/point_history_classifier.keras
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 190ms/step - accuracy: 0.7433 - loss: 0.6077 - val_accuracy: 0.8095 - val_loss: 0.4857
# Epoch 143/1000
# 1/2 ━━━━━━━━━━━━━━━━━━━━ 0s 58ms/step - accuracy: 0.6797 - loss: 0.6693
# Epoch 143: saving model to model/point_history_classifier/point_history_classifier.keras
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 206ms/step - accuracy: 0.6952 - loss: 0.6317 - val_accuracy: 0.8095 - val_loss: 0.4850
# Epoch 144/1000
# 1/2 ━━━━━━━━━━━━━━━━━━━━ 0s 59ms/step - accuracy: 0.7969 - loss: 0.5341
# Epoch 144: saving model to model/point_history_classifier/point_history_classifier.keras
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 219ms/step - accuracy: 0.8128 - loss: 0.5501 - val_accuracy: 0.8095 - val_loss: 0.4820
# Epoch 145/1000
# 1/2 ━━━━━━━━━━━━━━━━━━━━ 0s 71ms/step - accuracy: 0.7656 - loss: 0.5637
# Epoch 145: saving model to model/point_history_classifier/point_history_classifier.keras
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 199ms/step - accuracy: 0.7112 - loss: 0.6492 - val_accuracy: 0.8095 - val_loss: 0.4791
# Epoch 146/1000
# 1/2 ━━━━━━━━━━━━━━━━━━━━ 0s 71ms/step - accuracy: 0.7578 - loss: 0.5758
# Epoch 146: saving model to model/point_history_classifier/point_history_classifier.keras
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 207ms/step - accuracy: 0.7433 - loss: 0.6007 - val_accuracy: 0.8095 - val_loss: 0.4757
# Epoch 147/1000
# 1/2 ━━━━━━━━━━━━━━━━━━━━ 0s 63ms/step - accuracy: 0.7578 - loss: 0.5478
# Epoch 147: saving model to model/point_history_classifier/point_history_classifier.keras
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 215ms/step - accuracy: 0.7326 - loss: 0.5875 - val_accuracy: 0.8254 - val_loss: 0.4738
# Epoch 148/1000
# 1/2 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step - accuracy: 0.7422 - loss: 0.6229
# Epoch 148: saving model to model/point_history_classifier/point_history_classifier.keras
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 216ms/step - accuracy: 0.7701 - loss: 0.5803 - val_accuracy: 0.8254 - val_loss: 0.4723
# Epoch 149/1000
# 1/2 ━━━━━━━━━━━━━━━━━━━━ 0s 69ms/step - accuracy: 0.8281 - loss: 0.4914
# Epoch 149: saving model to model/point_history_classifier/point_history_classifier.keras
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 192ms/step - accuracy: 0.7914 - loss: 0.5283 - val_accuracy: 0.8413 - val_loss: 0.4691
# Epoch 150/1000
# 1/2 ━━━━━━━━━━━━━━━━━━━━ 0s 64ms/step - accuracy: 0.7891 - loss: 0.5948
# Epoch 150: saving model to model/point_history_classifier/point_history_classifier.keras
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 192ms/step - accuracy: 0.7594 - loss: 0.5708 - val_accuracy: 0.8413 - val_loss: 0.4674
# Epoch 151/1000
# 1/2 ━━━━━━━━━━━━━━━━━━━━ 0s 79ms/step - accuracy: 0.7812 - loss: 0.5352
# Epoch 151: saving model to model/point_history_classifier/point_history_classifier.keras
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 206ms/step - accuracy: 0.7807 - loss: 0.5567 - val_accuracy: 0.8571 - val_loss: 0.4652
# Epoch 152/1000
# 1/2 ━━━━━━━━━━━━━━━━━━━━ 0s 68ms/step - accuracy: 0.7734 - loss: 0.5033
# Epoch 152: saving model to model/point_history_classifier/point_history_classifier.keras
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 193ms/step - accuracy: 0.7326 - loss: 0.5560 - val_accuracy: 0.8571 - val_loss: 0.4641
# Epoch 153/1000
# 1/2 ━━━━━━━━━━━━━━━━━━━━ 0s 52ms/step - accuracy: 0.8203 - loss: 0.5010
# Epoch 153: saving model to model/point_history_classifier/point_history_classifier.keras
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 207ms/step - accuracy: 0.8289 - loss: 0.4904 - val_accuracy: 0.8571 - val_loss: 0.4616
# Epoch 154/1000
# 1/2 ━━━━━━━━━━━━━━━━━━━━ 0s 63ms/step - accuracy: 0.8438 - loss: 0.5003
# Epoch 154: saving model to model/point_history_classifier/point_history_classifier.keras
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 207ms/step - accuracy: 0.8289 - loss: 0.5108 - val_accuracy: 0.8413 - val_loss: 0.4613
# Epoch 155/1000
# 1/2 ━━━━━━━━━━━━━━━━━━━━ 0s 64ms/step - accuracy: 0.7188 - loss: 0.6171
# Epoch 155: saving model to model/point_history_classifier/point_history_classifier.keras
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 199ms/step - accuracy: 0.7433 - loss: 0.5996 - val_accuracy: 0.8571 - val_loss: 0.4624
# Epoch 156/1000
# 1/2 ━━━━━━━━━━━━━━━━━━━━ 0s 67ms/step - accuracy: 0.7422 - loss: 0.5425
# Epoch 156: saving model to model/point_history_classifier/point_history_classifier.keras
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 190ms/step - accuracy: 0.7701 - loss: 0.5297 - val_accuracy: 0.8730 - val_loss: 0.4604
# Epoch 157/1000
# 1/2 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step - accuracy: 0.8125 - loss: 0.5554
# Epoch 157: saving model to model/point_history_classifier/point_history_classifier.keras
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 211ms/step - accuracy: 0.8075 - loss: 0.5251 - val_accuracy: 0.8730 - val_loss: 0.4553
# Epoch 158/1000
# 1/2 ━━━━━━━━━━━━━━━━━━━━ 0s 60ms/step - accuracy: 0.7266 - loss: 0.5621
# Epoch 158: saving model to model/point_history_classifier/point_history_classifier.keras
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 190ms/step - accuracy: 0.7594 - loss: 0.5481 - val_accuracy: 0.8730 - val_loss: 0.4474
# Epoch 159/1000
# 1/2 ━━━━━━━━━━━━━━━━━━━━ 0s 58ms/step - accuracy: 0.8047 - loss: 0.4872
# Epoch 159: saving model to model/point_history_classifier/point_history_classifier.keras
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 195ms/step - accuracy: 0.8342 - loss: 0.4910 - val_accuracy: 0.8730 - val_loss: 0.4392
# Epoch 160/1000
# 1/2 ━━━━━━━━━━━━━━━━━━━━ 0s 68ms/step - accuracy: 0.7656 - loss: 0.5617
# Epoch 160: saving model to model/point_history_classifier/point_history_classifier.keras
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 197ms/step - accuracy: 0.7594 - loss: 0.5663 - val_accuracy: 0.8571 - val_loss: 0.4317
# Epoch 161/1000
# 1/2 ━━━━━━━━━━━━━━━━━━━━ 0s 71ms/step - accuracy: 0.7578 - loss: 0.5752
# Epoch 161: saving model to model/point_history_classifier/point_history_classifier.keras
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 205ms/step - accuracy: 0.7701 - loss: 0.5505 - val_accuracy: 0.8730 - val_loss: 0.4278
# Epoch 162/1000
# 1/2 ━━━━━━━━━━━━━━━━━━━━ 0s 63ms/step - accuracy: 0.8516 - loss: 0.4741
# Epoch 162: saving model to model/point_history_classifier/point_history_classifier.keras
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 208ms/step - accuracy: 0.8396 - loss: 0.4782 - val_accuracy: 0.9048 - val_loss: 0.4236
# Epoch 163/1000
# 1/2 ━━━━━━━━━━━━━━━━━━━━ 0s 61ms/step - accuracy: 0.7812 - loss: 0.5425
# Epoch 163: saving model to model/point_history_classifier/point_history_classifier.keras
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 190ms/step - accuracy: 0.7807 - loss: 0.5470 - val_accuracy: 0.9048 - val_loss: 0.4220
# Epoch 164/1000
# 1/2 ━━━━━━━━━━━━━━━━━━━━ 0s 64ms/step - accuracy: 0.8359 - loss: 0.4516
# Epoch 164: saving model to model/point_history_classifier/point_history_classifier.keras
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 212ms/step - accuracy: 0.7914 - loss: 0.5158 - val_accuracy: 0.9206 - val_loss: 0.4191
# Epoch 165/1000
# 1/2 ━━━━━━━━━━━━━━━━━━━━ 0s 58ms/step - accuracy: 0.7969 - loss: 0.5328
# Epoch 165: saving model to model/point_history_classifier/point_history_classifier.keras
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 221ms/step - accuracy: 0.8075 - loss: 0.5157 - val_accuracy: 0.9206 - val_loss: 0.4143
# Epoch 166/1000
# 1/2 ━━━━━━━━━━━━━━━━━━━━ 0s 63ms/step - accuracy: 0.8125 - loss: 0.4810
# Epoch 166: saving model to model/point_history_classifier/point_history_classifier.keras
# ...
# Epoch 238: saving model to model/point_history_classifier/point_history_classifier.keras
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 195ms/step - accuracy: 0.8824 - loss: 0.3965 - val_accuracy: 0.9048 - val_loss: 0.3334
# Epoch 239/1000
# 1/2 ━━━━━━━━━━━━━━━━━━━━ 0s 57ms/step - accuracy: 0.8750 - loss: 0.3350
# Epoch 239: saving model to model/point_history_classifier/point_history_classifier.keras
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 204ms/step - accuracy: 0.8770 - loss: 0.3358 - val_accuracy: 0.8889 - val_loss: 0.3334
# Epoch 240/1000
# 1/2 ━━━━━━━━━━━━━━━━━━━━ 0s 61ms/step - accuracy: 0.8594 - loss: 0.2886
# Epoch 240: saving model to model/point_history_classifier/point_history_classifier.keras
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 207ms/step - accuracy: 0.8610 - loss: 0.2921 - val_accuracy: 0.8889 - val_loss: 0.3337
# Epoch 241/1000
# 1/2 ━━━━━━━━━━━━━━━━━━━━ 0s 64ms/step - accuracy: 0.8828 - loss: 0.3581
# Epoch 241: saving model to model/point_history_classifier/point_history_classifier.keras
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 210ms/step - accuracy: 0.8717 - loss: 0.3545 - val_accuracy: 0.9048 - val_loss: 0.3320
# Epoch 242/1000
# 1/2 ━━━━━━━━━━━━━━━━━━━━ 0s 63ms/step - accuracy: 0.8672 - loss: 0.3545
# Epoch 242: saving model to model/point_history_classifier/point_history_classifier.keras
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 191ms/step - accuracy: 0.8984 - loss: 0.3402 - val_accuracy: 0.9206 - val_loss: 0.3284
# Epoch 243/1000
# 1/2 ━━━━━━━━━━━━━━━━━━━━ 0s 80ms/step - accuracy: 0.8359 - loss: 0.4042
# Epoch 243: saving model to model/point_history_classifier/point_history_classifier.keras
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 206ms/step - accuracy: 0.8396 - loss: 0.3814 - val_accuracy: 0.9206 - val_loss: 0.3258
# Epoch 244/1000
# 1/2 ━━━━━━━━━━━━━━━━━━━━ 0s 53ms/step - accuracy: 0.8828 - loss: 0.2899
# Epoch 244: saving model to model/point_history_classifier/point_history_classifier.keras
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 202ms/step - accuracy: 0.8930 - loss: 0.2857 - val_accuracy: 0.9206 - val_loss: 0.3231
# Epoch 245/1000
# 1/2 ━━━━━━━━━━━━━━━━━━━━ 0s 64ms/step - accuracy: 0.8906 - loss: 0.3189
# Epoch 245: saving model to model/point_history_classifier/point_history_classifier.keras
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 189ms/step - accuracy: 0.8930 - loss: 0.3156 - val_accuracy: 0.9365 - val_loss: 0.3208
# Epoch 246/1000
# 1/2 ━━━━━━━━━━━━━━━━━━━━ 0s 63ms/step - accuracy: 0.8438 - loss: 0.3703
# Epoch 246: saving model to model/point_history_classifier/point_history_classifier.keras
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 222ms/step - accuracy: 0.8556 - loss: 0.3567 - val_accuracy: 0.9365 - val_loss: 0.3138
# Epoch 247/1000
# 1/2 ━━━━━━━━━━━━━━━━━━━━ 0s 58ms/step - accuracy: 0.8672 - loss: 0.3917
# Epoch 247: saving model to model/point_history_classifier/point_history_classifier.keras
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 195ms/step - accuracy: 0.8663 - loss: 0.3553 - val_accuracy: 0.9365 - val_loss: 0.3108
# Epoch 248/1000
# 1/2 ━━━━━━━━━━━━━━━━━━━━ 0s 63ms/step - accuracy: 0.8438 - loss: 0.3710
# Epoch 248: saving model to model/point_history_classifier/point_history_classifier.keras
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 208ms/step - accuracy: 0.8717 - loss: 0.3350 - val_accuracy: 0.9206 - val_loss: 0.3098
# Epoch 249/1000
# 1/2 ━━━━━━━━━━━━━━━━━━━━ 0s 59ms/step - accuracy: 0.8906 - loss: 0.2873
# Epoch 249: saving model to model/point_history_classifier/point_history_classifier.keras
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 218ms/step - accuracy: 0.8610 - loss: 0.3276 - val_accuracy: 0.9206 - val_loss: 0.3078
# Epoch 250/1000
# 1/2 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step - accuracy: 0.8906 - loss: 0.3029
# Epoch 250: saving model to model/point_history_classifier/point_history_classifier.keras
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 207ms/step - accuracy: 0.8717 - loss: 0.3251 - val_accuracy: 0.9206 - val_loss: 0.3070
# Epoch 251/1000
# 1/2 ━━━━━━━━━━━━━━━━━━━━ 0s 66ms/step - accuracy: 0.8906 - loss: 0.3129
# Epoch 251: saving model to model/point_history_classifier/point_history_classifier.keras
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 203ms/step - accuracy: 0.8824 - loss: 0.3119 - val_accuracy: 0.9048 - val_loss: 0.3072
# Epoch 252/1000
# 1/2 ━━━━━━━━━━━━━━━━━━━━ 0s 57ms/step - accuracy: 0.8672 - loss: 0.3509
# Epoch 252: saving model to model/point_history_classifier/point_history_classifier.keras
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 217ms/step - accuracy: 0.8984 - loss: 0.3061 - val_accuracy: 0.9206 - val_loss: 0.3064
# Epoch 253/1000
# 1/2 ━━━━━━━━━━━━━━━━━━━━ 0s 57ms/step - accuracy: 0.8672 - loss: 0.3836
# Epoch 253: saving model to model/point_history_classifier/point_history_classifier.keras
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 200ms/step - accuracy: 0.8824 - loss: 0.3368 - val_accuracy: 0.9206 - val_loss: 0.3051
# Epoch 254/1000
# 1/2 ━━━━━━━━━━━━━━━━━━━━ 0s 53ms/step - accuracy: 0.8906 - loss: 0.3290
# Epoch 254: saving model to model/point_history_classifier/point_history_classifier.keras
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 209ms/step - accuracy: 0.8984 - loss: 0.3031 - val_accuracy: 0.9206 - val_loss: 0.3074
# Epoch 255/1000
# 1/2 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step - accuracy: 0.9297 - loss: 0.2815
# Epoch 255: saving model to model/point_history_classifier/point_history_classifier.keras
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 217ms/step - accuracy: 0.9144 - loss: 0.2789 - val_accuracy: 0.9206 - val_loss: 0.3102
# Epoch 256/1000
# 1/2 ━━━━━━━━━━━━━━━━━━━━ 0s 57ms/step - accuracy: 0.8750 - loss: 0.3055
# Epoch 256: saving model to model/point_history_classifier/point_history_classifier.keras
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 198ms/step - accuracy: 0.8449 - loss: 0.3471 - val_accuracy: 0.9206 - val_loss: 0.3101
# Epoch 257/1000
# 1/2 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step - accuracy: 0.8906 - loss: 0.3018
# Epoch 257: saving model to model/point_history_classifier/point_history_classifier.keras
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 208ms/step - accuracy: 0.8717 - loss: 0.3261 - val_accuracy: 0.9206 - val_loss: 0.3015
# Epoch 258/1000
# 1/2 ━━━━━━━━━━━━━━━━━━━━ 0s 64ms/step - accuracy: 0.8281 - loss: 0.3899
# Epoch 258: saving model to model/point_history_classifier/point_history_classifier.keras
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 239ms/step - accuracy: 0.8610 - loss: 0.3468 - val_accuracy: 0.9206 - val_loss: 0.2931
# Epoch 259/1000
# 1/2 ━━━━━━━━━━━━━━━━━━━━ 0s 63ms/step - accuracy: 0.9375 - loss: 0.2421
# Epoch 259: saving model to model/point_history_classifier/point_history_classifier.keras
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 199ms/step - accuracy: 0.9198 - loss: 0.2646 - val_accuracy: 0.9365 - val_loss: 0.2914
# Epoch 260/1000
# 1/2 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step - accuracy: 0.8750 - loss: 0.3517
# Epoch 260: saving model to model/point_history_classifier/point_history_classifier.keras
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 209ms/step - accuracy: 0.8663 - loss: 0.3485 - val_accuracy: 0.9365 - val_loss: 0.2931
# Epoch 261/1000
# 1/2 ━━━━━━━━━━━━━━━━━━━━ 0s 64ms/step - accuracy: 0.8750 - loss: 0.2778
# Epoch 261: saving model to model/point_history_classifier/point_history_classifier.keras
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 204ms/step - accuracy: 0.8717 - loss: 0.2944 - val_accuracy: 0.9365 - val_loss: 0.2992
# Epoch 262/1000
# 1/2 ━━━━━━━━━━━━━━━━━━━━ 0s 58ms/step - accuracy: 0.9219 - loss: 0.2747
# Epoch 262: saving model to model/point_history_classifier/point_history_classifier.keras
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 196ms/step - accuracy: 0.9198 - loss: 0.2667 - val_accuracy: 0.9365 - val_loss: 0.3038
# Epoch 263/1000
# 1/2 ━━━━━━━━━━━━━━━━━━━━ 0s 64ms/step - accuracy: 0.8828 - loss: 0.3310
# Epoch 263: saving model to model/point_history_classifier/point_history_classifier.keras
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 191ms/step - accuracy: 0.8770 - loss: 0.3177 - val_accuracy: 0.9365 - val_loss: 0.3104
# Epoch 264/1000
# 1/2 ━━━━━━━━━━━━━━━━━━━━ 0s 63ms/step - accuracy: 0.9141 - loss: 0.2804
# Epoch 264: saving model to model/point_history_classifier/point_history_classifier.keras
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 222ms/step - accuracy: 0.9198 - loss: 0.2773 - val_accuracy: 0.9206 - val_loss: 0.3176
# Epoch 265/1000
# 1/2 ━━━━━━━━━━━━━━━━━━━━ 0s 54ms/step - accuracy: 0.8906 - loss: 0.3109
# Epoch 265: saving model to model/point_history_classifier/point_history_classifier.keras
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 208ms/step - accuracy: 0.8930 - loss: 0.3038 - val_accuracy: 0.9206 - val_loss: 0.3269
# Epoch 266/1000
# 1/2 ━━━━━━━━━━━━━━━━━━━━ 0s 61ms/step - accuracy: 0.8203 - loss: 0.3663
# Epoch 266: saving model to model/point_history_classifier/point_history_classifier.keras
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 191ms/step - accuracy: 0.8503 - loss: 0.3272 - val_accuracy: 0.9206 - val_loss: 0.3306
# Epoch 267/1000
# 1/2 ━━━━━━━━━━━━━━━━━━━━ 0s 53ms/step - accuracy: 0.8906 - loss: 0.3184
# Epoch 267: saving model to model/point_history_classifier/point_history_classifier.keras
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 225ms/step - accuracy: 0.8770 - loss: 0.3322 - val_accuracy: 0.9206 - val_loss: 0.3178
# Epoch 268/1000
# 1/2 ━━━━━━━━━━━━━━━━━━━━ 0s 64ms/step - accuracy: 0.8906 - loss: 0.2866
# Epoch 268: saving model to model/point_history_classifier/point_history_classifier.keras
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 191ms/step - accuracy: 0.8610 - loss: 0.3229 - val_accuracy: 0.9206 - val_loss: 0.3052
# Epoch 269/1000
# 1/2 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step - accuracy: 0.8750 - loss: 0.3344
# Epoch 269: saving model to model/point_history_classifier/point_history_classifier.keras
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 207ms/step - accuracy: 0.8930 - loss: 0.2973 - val_accuracy: 0.9206 - val_loss: 0.2930
# Epoch 270/1000
# 1/2 ━━━━━━━━━━━━━━━━━━━━ 0s 74ms/step - accuracy: 0.8906 - loss: 0.2725
# Epoch 270: saving model to model/point_history_classifier/point_history_classifier.keras
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 207ms/step - accuracy: 0.8824 - loss: 0.2759 - val_accuracy: 0.9365 - val_loss: 0.2836
# Epoch 271/1000
# 1/2 ━━━━━━━━━━━━━━━━━━━━ 0s 64ms/step - accuracy: 0.8984 - loss: 0.2678
# Epoch 271: saving model to model/point_history_classifier/point_history_classifier.keras
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 206ms/step - accuracy: 0.9037 - loss: 0.2743 - val_accuracy: 0.9365 - val_loss: 0.2811
# Epoch 272/1000
# 1/2 ━━━━━━━━━━━━━━━━━━━━ 0s 64ms/step - accuracy: 0.8750 - loss: 0.3306
# Epoch 272: saving model to model/point_history_classifier/point_history_classifier.keras
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 197ms/step - accuracy: 0.8930 - loss: 0.2820 - val_accuracy: 0.9206 - val_loss: 0.2808
# Epoch 273/1000
# 1/2 ━━━━━━━━━━━━━━━━━━━━ 0s 53ms/step - accuracy: 0.9141 - loss: 0.3142
# Epoch 273: saving model to model/point_history_classifier/point_history_classifier.keras
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 223ms/step - accuracy: 0.8984 - loss: 0.3128 - val_accuracy: 0.9206 - val_loss: 0.2832
# Epoch 274/1000
# 1/2 ━━━━━━━━━━━━━━━━━━━━ 0s 64ms/step - accuracy: 0.8984 - loss: 0.3081
# Epoch 274: saving model to model/point_history_classifier/point_history_classifier.keras
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 200ms/step - accuracy: 0.8824 - loss: 0.3390 - val_accuracy: 0.9206 - val_loss: 0.2880
# Epoch 275/1000
# 1/2 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step - accuracy: 0.8984 - loss: 0.2456
# Epoch 275: saving model to model/point_history_classifier/point_history_classifier.keras
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 197ms/step - accuracy: 0.8877 - loss: 0.2651 - val_accuracy: 0.9206 - val_loss: 0.2967
# Epoch 276/1000
# 1/2 ━━━━━━━━━━━━━━━━━━━━ 0s 63ms/step - accuracy: 0.8828 - loss: 0.3466
# Epoch 276: saving model to model/point_history_classifier/point_history_classifier.keras
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 223ms/step - accuracy: 0.8824 - loss: 0.3181 - val_accuracy: 0.9206 - val_loss: 0.3097
# Epoch 277/1000
# 1/2 ━━━━━━━━━━━━━━━━━━━━ 0s 64ms/step - accuracy: 0.8984 - loss: 0.3219
# Epoch 277: saving model to model/point_history_classifier/point_history_classifier.keras
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 191ms/step - accuracy: 0.9037 - loss: 0.3043 - val_accuracy: 0.9206 - val_loss: 0.3148
# Epoch 278/1000
# 1/2 ━━━━━━━━━━━━━━━━━━━━ 0s 59ms/step - accuracy: 0.8984 - loss: 0.2938
# Epoch 278: saving model to model/point_history_classifier/point_history_classifier.keras
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 212ms/step - accuracy: 0.8984 - loss: 0.2815 - val_accuracy: 0.9206 - val_loss: 0.3157
# Epoch 279/1000
# 1/2 ━━━━━━━━━━━━━━━━━━━━ 0s 74ms/step - accuracy: 0.8984 - loss: 0.3091
# Epoch 279: saving model to model/point_history_classifier/point_history_classifier.keras
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 195ms/step - accuracy: 0.8984 - loss: 0.2929 - val_accuracy: 0.9206 - val_loss: 0.3105
# Epoch 280/1000
# 1/2 ━━━━━━━━━━━━━━━━━━━━ 0s 63ms/step - accuracy: 0.8984 - loss: 0.2508
# Epoch 280: saving model to model/point_history_classifier/point_history_classifier.keras
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 208ms/step - accuracy: 0.9091 - loss: 0.2631 - val_accuracy: 0.9206 - val_loss: 0.3085
# Epoch 281/1000
# 1/2 ━━━━━━━━━━━━━━━━━━━━ 0s 63ms/step - accuracy: 0.9141 - loss: 0.2660
# Epoch 281: saving model to model/point_history_classifier/point_history_classifier.keras
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 218ms/step - accuracy: 0.9144 - loss: 0.2567 - val_accuracy: 0.9048 - val_loss: 0.3065
# Epoch 282/1000
# 1/2 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step - accuracy: 0.8125 - loss: 0.4569
# Epoch 282: saving model to model/point_history_classifier/point_history_classifier.keras
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 201ms/step - accuracy: 0.8396 - loss: 0.3965 - val_accuracy: 0.9048 - val_loss: 0.2944
# Epoch 283/1000
# 1/2 ━━━━━━━━━━━━━━━━━━━━ 0s 69ms/step - accuracy: 0.9297 - loss: 0.2048
# Epoch 283: saving model to model/point_history_classifier/point_history_classifier.keras
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 208ms/step - accuracy: 0.9305 - loss: 0.2061 - val_accuracy: 0.9206 - val_loss: 0.2855
# Epoch 284/1000
# 1/2 ━━━━━━━━━━━━━━━━━━━━ 0s 73ms/step - accuracy: 0.8828 - loss: 0.3129
# Epoch 284: saving model to model/point_history_classifier/point_history_classifier.keras
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 198ms/step - accuracy: 0.8984 - loss: 0.2820 - val_accuracy: 0.9206 - val_loss: 0.2809
# Epoch 285/1000
# 1/2 ━━━━━━━━━━━━━━━━━━━━ 0s 63ms/step - accuracy: 0.9062 - loss: 0.2705
# Epoch 285: saving model to model/point_history_classifier/point_history_classifier.keras
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 202ms/step - accuracy: 0.8770 - loss: 0.3366 - val_accuracy: 0.9206 - val_loss: 0.2818
# Epoch 286/1000
# 1/2 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step - accuracy: 0.8750 - loss: 0.2886
# Epoch 286: saving model to model/point_history_classifier/point_history_classifier.keras
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 233ms/step - accuracy: 0.8824 - loss: 0.2915 - val_accuracy: 0.9206 - val_loss: 0.2923
# Epoch 287/1000
# 1/2 ━━━━━━━━━━━━━━━━━━━━ 0s 53ms/step - accuracy: 0.9062 - loss: 0.2779
# Epoch 287: saving model to model/point_history_classifier/point_history_classifier.keras
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 207ms/step - accuracy: 0.9091 - loss: 0.2705 - val_accuracy: 0.9206 - val_loss: 0.3056
# Epoch 288/1000
# 1/2 ━━━━━━━━━━━━━━━━━━━━ 0s 63ms/step - accuracy: 0.9062 - loss: 0.2334
# Epoch 288: saving model to model/point_history_classifier/point_history_classifier.keras
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 218ms/step - accuracy: 0.8984 - loss: 0.2553 - val_accuracy: 0.9206 - val_loss: 0.3188
# Epoch 289/1000
# 1/2 ━━━━━━━━━━━━━━━━━━━━ 0s 64ms/step - accuracy: 0.8984 - loss: 0.2365
# Epoch 289: saving model to model/point_history_classifier/point_history_classifier.keras
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 195ms/step - accuracy: 0.8930 - loss: 0.2706 - val_accuracy: 0.9206 - val_loss: 0.3275
# Epoch 290/1000
# 1/2 ━━━━━━━━━━━━━━━━━━━━ 0s 70ms/step - accuracy: 0.8828 - loss: 0.2635
# Epoch 290: saving model to model/point_history_classifier/point_history_classifier.keras
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 202ms/step - accuracy: 0.8503 - loss: 0.3172 - val_accuracy: 0.9206 - val_loss: 0.3318
# Epoch 291/1000
# 1/2 ━━━━━━━━━━━━━━━━━━━━ 0s 63ms/step - accuracy: 0.9141 - loss: 0.2803
# Epoch 291: saving model to model/point_history_classifier/point_history_classifier.keras
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 222ms/step - accuracy: 0.9144 - loss: 0.2773 - val_accuracy: 0.9206 - val_loss: 0.3326
# Epoch 292/1000
# 1/2 ━━━━━━━━━━━━━━━━━━━━ 0s 63ms/step - accuracy: 0.9141 - loss: 0.2276
# Epoch 292: saving model to model/point_history_classifier/point_history_classifier.keras
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 208ms/step - accuracy: 0.9037 - loss: 0.2564 - val_accuracy: 0.9206 - val_loss: 0.3349
# Epoch 292: early stopping

# %%
# 保存したモデルのロード
model = tf.keras.models.load_model(model_save_path)

# %%
# 推論テスト
predict_result = model.predict(np.array([X_test[0]]))
print(np.squeeze(predict_result))
print(np.argmax(np.squeeze(predict_result)))
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 206ms/step
# [7.3738918e-02 2.6642548e-02 5.5119017e-06 8.8277870e-01 1.6834296e-02]
# 3

# %% [markdown]
# # 混同行列

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
from sklearn.metrics import confusion_matrix, classification_report

def print_confusion_matrix(y_true, y_pred, report=True):
    labels = sorted(list(set(y_true)))
    cmx_data = confusion_matrix(y_true, y_pred, labels=labels)
    
    df_cmx = pd.DataFrame(cmx_data, index=labels, columns=labels)
 
    fig, ax = plt.subplots(figsize=(7, 6))
    sns.heatmap(df_cmx, annot=True, fmt='g' ,square=False)
    ax.set_ylim(len(set(y_true)), 0)
    plt.show()
    
    if report:
        print('Classification Report')
        print(classification_report(y_test, y_pred))

Y_pred = model.predict(X_test)
y_pred = np.argmax(Y_pred, axis=1)

print_confusion_matrix(y_test, y_pred)
# horizontal axis: real class
# vertical axis: predicted class
# on the diagonal true predictions, other areas are false predictions
# Out:
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step
# Classification Report
#               precision    recall  f1-score   support
#
#            0       0.93      0.87      0.90        15
#            1       1.00      0.80      0.89        10
#            2       0.87      1.00      0.93        13
#            3       0.95      0.95      0.95        19
#            4       0.86      1.00      0.92         6
#
#     accuracy                           0.92        63
#    macro avg       0.92      0.92      0.92        63
# weighted avg       0.93      0.92      0.92        63

# %% [markdown]
# # Tensorflow-Lite用のモデルへ変換

# %%
# 推論専用のモデルとして保存
model.save(model_save_path, include_optimizer=False)
model = tf.keras.models.load_model(model_save_path)

# %%
tflite_save_path = 'model/point_history_classifier/point_history_classifier.tflite'

# %%
# モデルを変換(量子化
converter = tf.lite.TFLiteConverter.from_keras_model(model)  # converter = tf.lite.TFLiteConverter.from_saved_model(saved_model_path)

converter.target_spec.supported_ops = [
    tf.lite.OpsSet.TFLITE_BUILTINS,
]
tflite_quantized_model = converter.convert()

open(tflite_save_path, 'wb').write(tflite_quantized_model)
# Out:
# INFO:tensorflow:Assets written to: C:\Users\Acer\AppData\Local\Temp\tmphnj3tobn\assets
# INFO:tensorflow:Assets written to: C:\Users\Acer\AppData\Local\Temp\tmphnj3tobn\assets
# Saved artifact at 'C:\Users\Acer\AppData\Local\Temp\tmphnj3tobn'. The following endpoints are available:
#
# * Endpoint 'serve'
#   args_0 (POSITIONAL_ONLY): TensorSpec(shape=(None, 80), dtype=tf.float32, name='input_layer')
# Output Type:
#   TensorSpec(shape=(None, 5), dtype=tf.float32, name=None)
# Captures:
#   2382216533216: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2382216538496: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2382304301248: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2382304303888: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2382304304416: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2382304302480: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2382304306704: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2382304398848: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2382304399376: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2382304402544: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2382304407120: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2382304407824: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2382304410464: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2382304411344: TensorSpec(shape=(), dtype=tf.resource, name=None)
# 22592

# %% [markdown]
# # 推論テスト

# %%
interpreter = tf.lite.Interpreter(model_path=tflite_save_path)
interpreter.allocate_tensors()
# Out:
# C:\Users\Acer\AppData\Local\Programs\Python\Python310\lib\site-packages\tensorflow\lite\python\interpreter.py:457: UserWarning:     Warning: tf.lite.Interpreter is deprecated and is scheduled for deletion in
#     TF 2.20. Please use the LiteRT interpreter from the ai_edge_litert package.
#     See the [migration guide](https://ai.google.dev/edge/litert/migration)
#     for details.
#
#   warnings.warn(_INTERPRETER_DELETION_WARNING)

# %%
# 入出力テンソルを取得
input_details = interpreter.get_input_details()
output_details = interpreter.get_output_details()
print(input_details)
# Out:
# [{'name': 'serving_default_input_layer:0', 'index': 0, 'shape': array([ 1, 80], dtype=int32), 'shape_signature': array([-1, 80], dtype=int32), 'dtype': <class 'numpy.float32'>, 'quantization': (0.0, 0), 'quantization_parameters': {'scales': array([], dtype=float32), 'zero_points': array([], dtype=int32), 'quantized_dimension': 0, 'block_size': 0}, 'sparsity_parameters': {}}]

# %%
interpreter.set_tensor(input_details[0]['index'], np.array([X_test[0]]))

# %%
# %%time
# 推論実施
interpreter.invoke()
tflite_results = interpreter.get_tensor(output_details[0]['index'])
# Out:
# CPU times: total: 15.6 ms
# Wall time: 2 ms

# %%
print(np.squeeze(tflite_results))
print(np.argmax(np.squeeze(tflite_results)))
# Out:
# [7.3738970e-02 2.6642516e-02 5.5119121e-06 8.8277870e-01 1.6834280e-02]
# 3
